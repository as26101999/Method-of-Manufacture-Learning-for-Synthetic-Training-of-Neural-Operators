# %%
# ============================
# 1D NONLINEAR DIFFUSION–REACTION (Periodic x)
# PDE: u_t - nu u_xx - (u - u^3) = f
# Inputs: [f, X, T, U0]  -> Output: u(t,x)
# ============================
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import os, random

# ------------------ Matplotlib style (Nature-style-ish) ------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 11,
    "axes.labelsize": 11,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "lines.linewidth": 2.0,
    "axes.linewidth": 1.0,
    "figure.dpi": 150,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

# ------------------ Repro & Device ------------------
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True, warn_only=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

# ------------------ Config (NONLINEAR DIFF–REACTION) ------------------
Nx, Nt   = 128, 128
Lx       = 2*np.pi
Tfinal   = 1
nu       = 5e-2     # diffusion coefficient (positive, keeps things smooth)

batch_size = 64
train_samples, val_samples = 1024, 32
modes_t, modes_x = 40, 40
width, depth = 64, 4
epochs, lr = 300, 2e-3

# Physics-loss weights
lambda_phys =  1.0      # PDE residual
lambda_ic   =  1.0      # IC consistency at t=0
lambda_bc   =  1.0      # periodic BC consistency in x

CKPT_PATH_MSE  = "fno_nl_diffreact1d_pinn_best_mse.pt"
CKPT_PATH_RL2  = "fno_nl_diffreact1d_pinn_best_rl2.pt"

# ------------------ Grids & NumPy Derivatives ------------------
def make_grids(Nx, Nt, Lx, Tfinal):
    x = np.linspace(0, Lx, Nx, endpoint=False)
    t = np.linspace(0, Tfinal, Nt, endpoint=True)
    X, T = np.meshgrid(x, t, indexing='xy')  # (Nt,Nx)
    return x, t, X, T

def kvec(Nx, Lx):
    dx = Lx / Nx
    return 2*np.pi * np.fft.fftfreq(Nx, d=dx)

def dx_spectral(u, kx):
    U  = np.fft.fft(u, axis=1)
    dU = (1j * kx[None,:]) * U
    return np.fft.ifft(dU, axis=1).real

def dxx_spectral(u, kx):
    U   = np.fft.fft(u, axis=1)
    ddU = (-(kx[None,:]**2)) * U
    return np.fft.ifft(ddU, axis=1).real

def dt_finite(u, t):
    Nt = u.shape[0]
    ut = np.zeros_like(u)
    ut[1:-1] = (u[2:] - u[:-2]) / (t[2:,None] - t[:-2,None])
    ut[0]    = (u[1] - u[0])   / (t[1] - t[0])
    ut[-1]   = (u[-1] - u[-2]) / (t[-1] - t[-2])
    return ut

# ------------------ Manufactured fields ------------------
def manufactured_u(X, T, seed=None, Kx=5, Kt=3, kx_max=6, wt_max=6,
                   a_spatial=(0.05, 0.35), a_time=(0.2, 1.0), target_std=0.5):
    """
    u(x,t) = sum_{i=1..Kx} sum_{j=1..Kt} A_i * B_j * sin(k_i x + phi_i) * sin(w_j t + psi_j)
    Periodic in x; smooth in t.
    """
    rng  = np.random.default_rng(seed)
    kset = rng.integers(1, kx_max+1, size=Kx)
    wset = rng.integers(1, wt_max+1, size=Kt)
    A    = rng.uniform(*a_spatial, size=Kx) * rng.choice([-1,1], size=Kx)
    B    = rng.uniform(*a_time,   size=Kt) * rng.choice([-1,1], size=Kt)
    phi  = rng.uniform(0, 2*np.pi, size=Kx)
    psi  = rng.uniform(0, 2*np.pi, size=Kt)

    u = np.zeros_like(X, dtype=float)
    for ki, Ai, ph in zip(kset, A, phi):
        sx = np.sin(ki*X + ph)
        for wj, Bj, ps in zip(wset, B, psi):
            st = np.sin(wj*T + ps)
            u += Ai * Bj * sx * st

    # normalize amplitude
    u = u - u.mean()
    std = u.std()
    if std > 1e-8:
        u *= (target_std/std)
    return u

# ------------------ Dataset (NONLINEAR DIFF–REACTION) ------------------
class NonlinearDiffReact1DManufacturedDataset(Dataset):
    """
    PDE: u_t - nu u_xx - (u - u^3) = f
    We manufacture u(x,t), then compute f := u_t - nu u_xx - (u - u^3).
    """
    def __init__(self, n_samples, Nx, Nt, Lx, Tfinal, nu):
        self.n = n_samples
        self.x, self.t, self.X, self.T = make_grids(Nx, Nt, Lx, Tfinal)
        self.kx = kvec(Nx, Lx)
        self.nu = nu
        self.data = []

        for i in range(n_samples):
            u   = manufactured_u(self.X, self.T, seed=SEED + i)
            ut  = dt_finite(u, self.t)          # time derivative
            uxx = dxx_spectral(u, self.kx)      # second derivative
            reaction = u - u**3                 # Allen–Cahn-type
            # Correct PDE: u_t - nu u_xx - (u - u^3) = f
            f   = ut - self.nu * uxx - reaction

            u0 = u[0:1, :]                      # IC row
            U0 = np.tile(u0, (Nt, 1))           # broadcast in time

            inp = np.stack([f, self.X, self.T, U0], axis=0).astype(np.float32)  # [4,Nt,Nx]
            out = u.astype(np.float32)                                          # [Nt,Nx]
            self.data.append((inp, out))

    def __len__(self): return self.n
    def __getitem__(self, i):
        x, y = self.data[i]
        return torch.from_numpy(x), torch.from_numpy(y)

# ------------------ FNO blocks (unchanged) ------------------
class SpectralConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super().__init__()
        self.in_channels  = in_channels
        self.out_channels = out_channels
        self.modes1       = modes1
        self.modes2       = modes2
        scale = 1.0 / (in_channels * out_channels)
        self.weights1 = nn.Parameter(scale * torch.randn(
            in_channels, out_channels, modes1, modes2, dtype=torch.cfloat))
        self.weights2 = nn.Parameter(scale * torch.randn(
            in_channels, out_channels, modes1, modes2, dtype=torch.cfloat))

    def compl_mul2d(self, input, weights):
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        B, C, H, W = x.shape            # H ~ Nt, W ~ Nx
        x_ft = torch.fft.rfft2(x, norm="ortho")
        out_ft = torch.zeros(B, self.out_channels, H, W//2+1,
                             device=x.device, dtype=torch.cfloat)
        Hm = min(self.modes1, H)
        Wm = min(self.modes2, W//2 + 1)
        out_ft[:, :, :Hm, :Wm]   = self.compl_mul2d(x_ft[:, :, :Hm, :Wm], self.weights1[:, :, :Hm, :Wm])
        out_ft[:, :, -Hm:, :Wm]  = self.compl_mul2d(x_ft[:, :, -Hm:, :Wm], self.weights2[:, :, :Hm, :Wm])
        x = torch.fft.irfft2(out_ft, s=(H, W), norm="ortho")
        return x

class FNO2d(nn.Module):
    def __init__(self, in_channels, out_channels, width, modes1, modes2, depth=4):
        super().__init__()
        self.width  = width
        self.depth  = depth
        self.fc0    = nn.Conv2d(in_channels, width, 1)
        self.fourier = nn.ModuleList([SpectralConv2d(width, width, modes1, modes2) for _ in range(depth)])
        self.w       = nn.ModuleList([nn.Conv2d(width, width, 1) for _ in range(depth)])
        self.act     = nn.GELU()
        self.fc1     = nn.Conv2d(width, width, 1)
        self.fc2     = nn.Conv2d(width, out_channels, 1)

    def forward(self, x):
        x = self.fc0(x)
        for i in range(self.depth):
            y = self.fourier[i](x)
            x = self.act(y + self.w[i](x))
        x = self.act(self.fc1(x))
        x = self.fc2(x)
        return x

# ------------------ Torch Physics Helpers (NONLINEAR DIFF–REACTION) ------------------
def torch_kvec(Nx, Lx, device):
    dx  = Lx / Nx
    kx  = 2*np.pi * np.fft.fftfreq(Nx, d=dx)
    return torch.tensor(kx, dtype=torch.float32, device=device)  # [Nx]

def torch_dxx_spectral(u, kx):
    """
    u: [B,Nt,Nx] real -> u_xx: [B,Nt,Nx] real
    """
    U   = torch.fft.fft(u, dim=-1)
    ddU = (-(kx**2))[None, None, :] * U
    uxx = torch.fft.ifft(ddU, dim=-1).real
    return uxx

def torch_dt_cdiff(u, t):
    """
    u: [B,Nt,Nx], t: [Nt] (torch or numpy)
    returns u_t: [B,Nt,Nx] (centered interior, one-sided at ends)
    """
    if not torch.is_tensor(t):
        t = torch.tensor(t, dtype=torch.float32, device=u.device)
    ut = torch.zeros_like(u)
    ut[:,1:-1,:] = (u[:,2:,:] - u[:,:-2,:]) / (t[2:].view(1,-1,1) - t[:-2].view(1,-1,1))
    ut[:,0,:]    = (u[:,1,:]   - u[:,0,:])   / (t[1] - t[0])
    ut[:,-1,:]   = (u[:,-1,:]  - u[:,-2,:])  / (t[-1] - t[-2])
    return ut

def physics_residual_nl_diffreact(pred_phys, xin_phys, nu, kx, t_vec):
    """
    pred_phys: [B,Nt,Nx] predicted u (physical)
    xin_phys : [B,4,Nt,Nx] with channel 0 = f (physical)
    PDE: u_t - nu u_xx - (u - u^3) = f
    returns R = u_t - nu u_xx - (u - u^3) - f  [B,Nt,Nx]
    """
    f_phys    = xin_phys[:,0]                         # [B,Nt,Nx]
    ut        = torch_dt_cdiff(pred_phys, t_vec)      # [B,Nt,Nx]
    uxx       = torch_dxx_spectral(pred_phys, kx)     # [B,Nt,Nx]
    reaction  = pred_phys - pred_phys**3
    R         = ut - nu*uxx - reaction - f_phys
    return R

# ------------------ Plotting utils ------------------
def plot_heatmap(field, X, T, title, xlabel="x", ylabel="t", cmap="coolwarm"):
    plt.figure(figsize=(4.0, 3.0))
    extent = [X.min(), X.max(), T.min(), T.max()]
    im = plt.imshow(field, aspect='auto', origin='lower', extent=extent, cmap=cmap)
    plt.xlabel(xlabel); plt.ylabel(ylabel); plt.title(title)
    cbar = plt.colorbar(im, fraction=0.046, pad=0.04)
    cbar.ax.tick_params(width=0.8, length=3)
    plt.tight_layout()
    plt.show()

def plot_time_slice_grid(x, t, kinds, pred_dict, ref_dict,
                         t_indices, t_labels):
    """
    Multi-panel figure:
      rows = time slices
      cols = IC types
      Each panel: Exact vs FNO.
    """
    nrows = len(t_indices)
    ncols = len(kinds)
    fig, axes = plt.subplots(nrows, ncols,
                             figsize=(3.0*ncols, 2.4*nrows),
                             sharex=True, sharey=False)

    if nrows == 1:
        axes = np.array([axes])
    if ncols == 1:
        axes = axes[:, np.newaxis]

    for ci, kind in enumerate(kinds):
        u_ref  = ref_dict[kind]
        u_pred = pred_dict[kind]
        for ri, (tidx, lbl) in enumerate(zip(t_indices, t_labels)):
            ax = axes[ri, ci]
            ax.plot(x, u_ref[tidx],  linestyle="-",  color="C0", linewidth=3.2, label="Exact")
            ax.plot(x, u_pred[tidx], linestyle="--", color="C1", linewidth=3.0, label="FNO")
            if ri == nrows-1:
                ax.set_xlabel(r"$x$")
            if ci == 0:
                ax.set_ylabel(r"$u(x,t)$")
            if ri == 0:
                ax.set_title(f"IC: {kind}")
            ax.text(0.98, 0.98, lbl,
                    transform=ax.transAxes,
                    fontsize=9, ha="right", va="top")
            ax.grid(alpha=0.2, linewidth=0.8)

    # One legend for the whole figure
    handles, labels = axes[0,0].get_legend_handles_labels()
    fig.legend(handles, labels,
               loc="upper center", ncol=2,
               frameon=False, bbox_to_anchor=(0.5, 1.02))
    plt.tight_layout()
    plt.show()

# ------------------ Build data ------------------
x, t, X, T = make_grids(Nx, Nt, Lx, Tfinal)
train_set  = NonlinearDiffReact1DManufacturedDataset(train_samples, Nx, Nt, Lx, Tfinal, nu)
val_set    = NonlinearDiffReact1DManufacturedDataset(val_samples,   Nx, Nt, Lx, Tfinal, nu)
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0)
val_loader   = DataLoader(val_set,   batch_size=batch_size, shuffle=False, num_workers=0)

xb, yb = next(iter(train_loader))
print("Batch shapes -> xin:", tuple(xb.shape), " y:", tuple(yb.shape))

# ------------------ Init model ------------------
model = FNO2d(in_channels=4, out_channels=1, width=width,
              modes1=modes_t, modes2=modes_x, depth=depth).to(device)
with torch.no_grad():
    _ = model(xb.to(device).float())
print("Fwd pass ok.")

# ------------------ Eval helper (physical metrics) ------------------
def evaluate(model, loader, device):
    model.eval()
    mse_fn = nn.MSELoss(reduction="mean")
    tot_mse, tot_rl2, n = 0.0, 0.0, 0
    with torch.no_grad():
        for xin, y in loader:
            xin = xin.to(device).float()             # [B,4,Nt,Nx]
            y   = y.to(device).unsqueeze(1).float()  # [B,1,Nt,Nx]
            pred = model(xin)                        # [B,1,Nt,Nx]
            mse = mse_fn(pred, y).item()
            num = torch.linalg.vector_norm((pred - y).reshape(pred.size(0), -1), dim=1)
            den = torch.linalg.vector_norm(y.reshape(y.size(0), -1), dim=1) + 1e-12
            rl2 = (num/den).mean().item()
            bs = xin.size(0)
            tot_mse += mse * bs; tot_rl2 += rl2 * bs; n += bs
    return tot_mse/max(n,1), tot_rl2/max(n,1)

# ------------------ Train: MSE + λ_phys*||R||² + λ_ic*||u(0)-U0||² + λ_bc*||u(.,0)-u(.,Lx)||² ------------------
def train_fno_pinn(model, train_loader, val_loader,
                   epochs=epochs, lr=lr, device=device,
                   Lx=Lx, Tfinal=Tfinal, nu=nu,
                   lambda_phys=lambda_phys, lambda_ic=lambda_ic, lambda_bc=lambda_bc):
    opt   = torch.optim.Adam(model.parameters(), lr=lr)
    sched = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', factor=0.5, patience=30)
    mse   = nn.MSELoss()

    # torch grids for physics terms
    kx    = torch_kvec(Nx, Lx, device)
    t_vec = torch.tensor(np.linspace(0, Tfinal, Nt, endpoint=True),
                         dtype=torch.float32, device=device)

    best = {
        "val_mse": float("inf"),
        "val_rl2": float("inf"),
        "epoch_mse": -1,
        "epoch_rl2": -1,
    }

    # ---- history containers ----
    history = {
        "data":   [],
        "phys":   [],
        "ic":     [],
        "bc":     [],
        "tot":    [],
        "val_mse": [],
        "val_rl2": []
    }

    for ep in range(1, epochs+1):
        model.train()
        running = {"data":0.0, "phys":0.0, "ic":0.0, "bc":0.0, "tot":0.0, "n":0}

        for xin_phys, y_phys in train_loader:
            xin_phys = xin_phys.to(device).float()               # [B,4,Nt,Nx]
            y_phys   = y_phys.to(device).unsqueeze(1).float()    # [B,1,Nt,Nx]

            # ---------------- Data loss ----------------
            pred = model(xin_phys)                               # [B,1,Nt,Nx]
            data_loss = mse(pred, y_phys)

            # ---------------- Physics residual loss ----------------
            pred_u = pred.squeeze(1)                             # [B,Nt,Nx]
            R = physics_residual_nl_diffreact(pred_u, xin_phys, nu, kx, t_vec)
            phys_loss = torch.mean(R * R)

            # ---------------- IC loss (t = 0) ----------------
            U0_line = xin_phys[:, 3, 0, :]                       # [B,Nx]
            ic_loss = torch.mean((pred_u[:, 0, :] - U0_line)**2)

            # ---------------- BC loss (periodic in x) ----------------
            left_vals  = pred_u[:, :, 0]                         # [B,Nt]
            right_vals = pred_u[:, :, -1]                        # [B,Nt]
            bc_loss = torch.mean((left_vals - right_vals)**2)

            # ---------------- Total loss ----------------
            loss = (data_loss
                    + lambda_phys * phys_loss
                    + lambda_ic   * ic_loss
                    + lambda_bc   * bc_loss)

            opt.zero_grad()
            loss.backward()
            opt.step()

            # ---------------- Bookkeeping ----------------
            B = xin_phys.size(0)
            running["data"] += data_loss.detach().item() * B
            running["phys"] += phys_loss.detach().item() * B
            running["ic"]   += ic_loss.detach().item()   * B
            running["bc"]   += bc_loss.detach().item()   * B
            running["tot"]  += loss.detach().item()      * B
            running["n"]    += B

        # ---------------- Per-epoch averages ----------------
        n = max(running["n"], 1)
        epoch_data = running["data"] / n
        epoch_phys = running["phys"] / n
        epoch_ic   = running["ic"]   / n
        epoch_bc   = running["bc"]   / n
        epoch_tot  = running["tot"]  / n

        # ---------------- Validation ----------------
        val_mse, val_rl2 = evaluate(model, val_loader, device)
        sched.step(val_mse)

        # ---- store in history ----
        history["data"].append(epoch_data)
        history["phys"].append(epoch_phys)
        history["ic"].append(epoch_ic)
        history["bc"].append(epoch_bc)
        history["tot"].append(epoch_tot)
        history["val_mse"].append(val_mse)
        history["val_rl2"].append(val_rl2)

        print(f"Epoch {ep:03d} | "
              f"train_tot={epoch_tot:.3e} "
              f"(data={epoch_data:.3e}, phys={epoch_phys:.3e}, "
              f"ic={epoch_ic:.3e}, bc={epoch_bc:.3e}) | "
              f"val_mse={val_mse:.3e} | val_relL2={val_rl2:.3e} | "
              f"lr={opt.param_groups[0]['lr']:.1e}")

        # ---- Best by val MSE ----
        if val_mse < best["val_mse"]:
            best["val_mse"]   = val_mse
            best["epoch_mse"] = ep
            torch.save({
                "model_state": model.state_dict(),
                "epoch": ep,
                "val_mse": val_mse,
                "val_rl2": val_rl2,
                "criterion": "val_mse",
                "config": {
                    "Nx": Nx, "Nt": Nt, "Lx": Lx, "Tfinal": Tfinal,
                    "nu": nu,
                    "modes_t": modes_t, "modes_x": modes_x,
                    "width": width, "depth": depth,
                    "lambda_phys": lambda_phys,
                    "lambda_ic": lambda_ic,
                    "lambda_bc": lambda_bc,
                }},
                CKPT_PATH_MSE)

        # ---- Best by val rel-L2 ----
        if val_rl2 < best["val_rl2"]:
            best["val_rl2"]   = val_rl2
            best["epoch_rl2"] = ep
            torch.save({
                "model_state": model.state_dict(),
                "epoch": ep,
                "val_mse": val_mse,
                "val_rl2": val_rl2,
                "criterion": "val_rl2",
                "config": {
                    "Nx": Nx, "Nt": Nt, "Lx": Lx, "Tfinal": Tfinal,
                    "nu": nu,
                    "modes_t": modes_t, "modes_x": modes_x,
                    "width": width, "depth": depth,
                    "lambda_phys": lambda_phys,
                    "lambda_ic": lambda_ic,
                    "lambda_bc": lambda_bc,
                }},
                CKPT_PATH_RL2)

    print(f"Best val_mse={best['val_mse']:.3e} @ epoch {best['epoch_mse']}")
    print(f"Best val_relL2={best['val_rl2']:.3e} @ epoch {best['epoch_rl2']}")

    return history

def plot_training_losses(history):
    epochs = np.arange(1, len(history["tot"]) + 1)

    plt.figure(figsize=(4.0, 3.0))
    plt.plot(epochs, history["data"], label=r"$\mathcal{L}_{\text{data}}$")
    plt.plot(epochs, history["phys"], label=r"$\mathcal{L}_{\text{phys}}$")
    plt.plot(epochs, history["ic"],   label=r"$\mathcal{L}_{\text{IC}}$")
    plt.plot(epochs, history["bc"],   label=r"$\mathcal{L}_{\text{BC}}$")
    plt.yscale("log")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training loss components (Nonlinear Diffusion–Reaction)")
    plt.grid(alpha=0.3, linewidth=0.8)
    plt.legend(frameon=False)
    plt.tight_layout()
    plt.show()

def plot_val_metrics(history):
    epochs = np.arange(1, len(history["val_mse"]) + 1)

    plt.figure(figsize=(4.0, 3.0))
    plt.plot(epochs, history["val_mse"], label="val MSE")
    plt.plot(epochs, history["val_rl2"], label="val rel-L2")
    plt.yscale("log")
    plt.xlabel("Epoch")
    plt.ylabel("Metric")
    plt.title("Validation metrics (Nonlinear Diffusion–Reaction)")
    plt.grid(alpha=0.3, linewidth=0.8)
    plt.legend(frameon=False)
    plt.tight_layout()
    plt.show()

print("=== Training (MSE + physics + IC + BC) — NONLINEAR DIFFUSION–REACTION ===")
history = train_fno_pinn(model, train_loader, val_loader)
plot_training_losses(history)
plot_val_metrics(history)

# ------------------ Inference utilities ------------------
def u0_fn(x, kind="two_mode"):
    if kind == "sine":
        return 0.8*np.sin(x)
    elif kind == "two_mode":
        return -0.5*np.sin(x) + 0.8*np.sin(3*x + 0.7)
    elif kind == "three_mode":
        return 0.9*np.sin(x) - 0.3*np.sin(3*x + 0.7) + 0.7*np.sin(5*x - 1.2)
    else:
        raise ValueError("unknown kind")

def nl_diffusion_reaction_reference(u0_row, nu, Nx, Nt, Lx, Tfinal):
    """
    Reference spectral RK4 solver for f=0:

    Correct PDE: u_t - nu u_xx - (u - u^3) = 0
      => u_t = nu u_xx + u - u^3
    """
    x = np.linspace(0, Lx, Nx, endpoint=False)
    t = np.linspace(0, Tfinal, Nt, endpoint=True)
    dt = t[1] - t[0]
    kx = kvec(Nx, Lx)

    def rhs(u):
        uxx = dxx_spectral(u[None, :], kx)[0]
        # Stable Allen–Cahn-type reaction
        return nu * uxx + u - u**3

    u = np.zeros((Nt, Nx), dtype=float)
    u[0] = u0_row.copy()

    for n in range(Nt-1):
        un = u[n]
        k1 = rhs(un)
        k2 = rhs(un + 0.5*dt*k1)
        k3 = rhs(un + 0.5*dt*k2)
        k4 = rhs(un + dt*k3)
        u[n+1] = un + (dt/6.0)*(k1 + 2*k2 + 2*k3 + k4)

    return u

# ------------------ Load best (by MSE) & test on f=0 ------------------
eval_model = FNO2d(in_channels=4, out_channels=1, width=width,
                   modes1=modes_t, modes2=modes_x, depth=depth).to(device)
ckpt = torch.load(CKPT_PATH_MSE, map_location=device)
eval_model.load_state_dict(ckpt["model_state"])
eval_model.eval()

kinds = ["sine", "two_mode", "three_mode"]
pred_dict = {}
ref_dict  = {}

for kind in kinds:
    print(f"\n=== Inference (Nonlinear Diffusion–Reaction): f=0, IC='{kind}' ===")
    x, t, X, T = make_grids(Nx, Nt, Lx, Tfinal)
    u0_row = u0_fn(x, kind=kind)
    U0     = np.tile(u0_row[None,:], (Nt,1))
    f_zero = np.zeros((Nt, Nx), dtype=np.float32)
    inp_np = np.stack([f_zero, X, T, U0], axis=0).astype(np.float32)  # [4,Nt,Nx]
    inp = torch.from_numpy(inp_np)[None].to(device)

    with torch.no_grad():
        pred = eval_model(inp).squeeze().detach().cpu().numpy()  # [Nt,Nx]

    # store for multi-IC comparison later
    pred_dict[kind] = pred
    u_ref = nl_diffusion_reaction_reference(u0_row, nu, Nx, Nt, Lx, Tfinal)
    ref_dict[kind]  = u_ref

    # Heatmap of prediction
    plot_heatmap(pred, X, T, title=f"FNO prediction (Nonlinear Diff-Reac), f=0, IC={kind}")

    # Physics residual: R = u_t - nu u_xx - (u - u^3) (since f=0 at inference)
    kx_np = kvec(Nx, Lx)
    ut  = dt_finite(pred, t)
    uxx = dxx_spectral(pred, kx_np)
    res = ut - nu*uxx - (pred - pred**3)
    plot_heatmap(res, X, T, title=f"Residual R(x,t), IC={kind}")

    # Reference heatmap
    plot_heatmap(u_ref, X, T, title=f"Reference u(x,t), IC={kind}")

    mse = np.mean((pred - u_ref)**2)
    relL2 = np.linalg.norm((pred - u_ref).ravel()) / (np.linalg.norm(u_ref.ravel()) + 1e-12)
    print("Ref comparison: MSE=%.3e | rel-L2=%.3e" % (mse, relL2))

# ------------------ Multi-IC, multi-time comparison plot ------------------
t_indices = [0, Nt//2, Nt-1]
t_labels  = [r"$t = 0$", rf"$t \approx {Tfinal/2:.2f}$", rf"$t = {Tfinal:.2f}$"]
plot_time_slice_grid(x, t, kinds, pred_dict, ref_dict, t_indices, t_labels)
# Out:
# Device: cuda
# Batch shapes -> xin: (64, 4, 128, 128)  y: (64, 128, 128)
# Fwd pass ok.
# === Training (MSE + physics + IC + BC) — NONLINEAR DIFFUSION–REACTION ===
# Epoch 001 | train_tot=2.827e+00 (data=1.775e-01, phys=2.374e+00, ic=2.741e-01, bc=1.983e-03) | val_mse=1.300e-01 | val_relL2=6.994e-01 | lr=2.0e-03
# Epoch 002 | train_tot=1.238e+00 (data=1.522e-01, phys=8.019e-01, ic=2.782e-01, bc=5.571e-03) | val_mse=1.227e-01 | val_relL2=6.679e-01 | lr=2.0e-03
# Epoch 003 | train_tot=9.659e-01 (data=1.366e-01, phys=5.882e-01, ic=2.353e-01, bc=5.837e-03) | val_mse=1.028e-01 | val_relL2=6.075e-01 | lr=2.0e-03
# Epoch 004 | train_tot=8.293e-01 (data=1.133e-01, phys=5.088e-01, ic=2.010e-01, bc=6.146e-03) | val_mse=7.095e-02 | val_relL2=4.805e-01 | lr=2.0e-03
# Epoch 005 | train_tot=7.191e-01 (data=8.125e-02, phys=4.814e-01, ic=1.501e-01, bc=6.386e-03) | val_mse=5.466e-02 | val_relL2=4.026e-01 | lr=2.0e-03
# Epoch 006 | train_tot=6.021e-01 (data=5.888e-02, phys=4.250e-01, ic=1.118e-01, bc=6.356e-03) | val_mse=3.544e-02 | val_relL2=3.319e-01 | lr=2.0e-03
# Epoch 007 | train_tot=4.109e-01 (data=3.223e-02, phys=3.183e-01, ic=5.378e-02, bc=6.544e-03) | val_mse=1.859e-02 | val_relL2=2.427e-01 | lr=2.0e-03
# Epoch 008 | train_tot=2.291e-01 (data=1.613e-02, phys=1.852e-01, ic=2.112e-02, bc=6.738e-03) | val_mse=9.411e-03 | val_relL2=1.711e-01 | lr=2.0e-03
# Epoch 009 | train_tot=1.360e-01 (data=9.711e-03, phys=1.101e-01, ic=9.174e-03, bc=7.005e-03) | val_mse=5.526e-03 | val_relL2=1.324e-01 | lr=2.0e-03
# Epoch 010 | train_tot=9.348e-02 (data=6.152e-03, phys=7.465e-02, ic=5.723e-03, bc=6.951e-03) | val_mse=3.811e-03 | val_relL2=1.075e-01 | lr=2.0e-03
# Epoch 011 | train_tot=7.468e-02 (data=4.323e-03, phys=5.916e-02, ic=4.220e-03, bc=6.974e-03) | val_mse=3.100e-03 | val_relL2=9.937e-02 | lr=2.0e-03
# Epoch 012 | train_tot=6.663e-02 (data=3.449e-03, phys=5.285e-02, ic=3.446e-03, bc=6.892e-03) | val_mse=2.409e-03 | val_relL2=8.701e-02 | lr=2.0e-03
# Epoch 013 | train_tot=4.854e-02 (data=2.918e-03, phys=3.600e-02, ic=2.766e-03, bc=6.856e-03) | val_mse=1.948e-03 | val_relL2=7.995e-02 | lr=2.0e-03
# Epoch 014 | train_tot=3.895e-02 (data=2.430e-03, phys=2.735e-02, ic=2.366e-03, bc=6.803e-03) | val_mse=1.694e-03 | val_relL2=7.390e-02 | lr=2.0e-03
# Epoch 015 | train_tot=3.163e-02 (data=2.010e-03, phys=2.104e-02, ic=1.853e-03, bc=6.733e-03) | val_mse=1.446e-03 | val_relL2=6.841e-02 | lr=2.0e-03
# Epoch 016 | train_tot=2.690e-02 (data=1.767e-03, phys=1.684e-02, ic=1.607e-03, bc=6.688e-03) | val_mse=1.164e-03 | val_relL2=6.309e-02 | lr=2.0e-03
# Epoch 017 | train_tot=2.501e-02 (data=1.525e-03, phys=1.544e-02, ic=1.385e-03, bc=6.656e-03) | val_mse=1.125e-03 | val_relL2=6.225e-02 | lr=2.0e-03
# Epoch 018 | train_tot=2.323e-02 (data=1.418e-03, phys=1.396e-02, ic=1.281e-03, bc=6.569e-03) | val_mse=9.244e-04 | val_relL2=5.551e-02 | lr=2.0e-03
# Epoch 019 | train_tot=2.139e-02 (data=1.254e-03, phys=1.248e-02, ic=1.123e-03, bc=6.531e-03) | val_mse=1.012e-03 | val_relL2=5.819e-02 | lr=2.0e-03
# Epoch 020 | train_tot=2.048e-02 (data=1.140e-03, phys=1.184e-02, ic=1.032e-03, bc=6.462e-03) | val_mse=8.908e-04 | val_relL2=5.414e-02 | lr=2.0e-03
# Epoch 021 | train_tot=2.176e-02 (data=1.043e-03, phys=1.336e-02, ic=9.341e-04, bc=6.417e-03) | val_mse=8.051e-04 | val_relL2=5.261e-02 | lr=2.0e-03
# Epoch 022 | train_tot=2.425e-02 (data=1.101e-03, phys=1.570e-02, ic=1.074e-03, bc=6.370e-03) | val_mse=8.075e-04 | val_relL2=5.194e-02 | lr=2.0e-03
# Epoch 023 | train_tot=2.858e-02 (data=1.125e-03, phys=2.007e-02, ic=1.062e-03, bc=6.323e-03) | val_mse=7.592e-04 | val_relL2=5.183e-02 | lr=2.0e-03
# Epoch 024 | train_tot=2.579e-02 (data=1.027e-03, phys=1.749e-02, ic=9.760e-04, bc=6.297e-03) | val_mse=9.124e-04 | val_relL2=5.551e-02 | lr=2.0e-03
# Epoch 025 | train_tot=2.275e-02 (data=9.803e-04, phys=1.453e-02, ic=9.772e-04, bc=6.261e-03) | val_mse=7.377e-04 | val_relL2=5.187e-02 | lr=2.0e-03
# Epoch 026 | train_tot=2.141e-02 (data=9.326e-04, phys=1.340e-02, ic=8.566e-04, bc=6.220e-03) | val_mse=7.418e-04 | val_relL2=5.143e-02 | lr=2.0e-03
# Epoch 027 | train_tot=2.001e-02 (data=8.010e-04, phys=1.224e-02, ic=7.815e-04, bc=6.185e-03) | val_mse=6.569e-04 | val_relL2=4.902e-02 | lr=2.0e-03
# Epoch 028 | train_tot=1.836e-02 (data=7.718e-04, phys=1.071e-02, ic=7.336e-04, bc=6.142e-03) | val_mse=5.219e-04 | val_relL2=4.363e-02 | lr=2.0e-03
# Epoch 029 | train_tot=1.721e-02 (data=7.006e-04, phys=9.679e-03, ic=6.987e-04, bc=6.129e-03) | val_mse=4.920e-04 | val_relL2=4.212e-02 | lr=2.0e-03
# Epoch 030 | train_tot=1.749e-02 (data=6.255e-04, phys=1.013e-02, ic=6.516e-04, bc=6.082e-03) | val_mse=4.698e-04 | val_relL2=4.088e-02 | lr=2.0e-03
# Epoch 031 | train_tot=1.571e-02 (data=6.117e-04, phys=8.374e-03, ic=6.423e-04, bc=6.085e-03) | val_mse=4.941e-04 | val_relL2=4.249e-02 | lr=2.0e-03
# Epoch 032 | train_tot=1.472e-02 (data=5.982e-04, phys=7.454e-03, ic=6.094e-04, bc=6.054e-03) | val_mse=4.068e-04 | val_relL2=3.840e-02 | lr=2.0e-03
# Epoch 033 | train_tot=1.415e-02 (data=5.659e-04, phys=6.984e-03, ic=5.887e-04, bc=6.014e-03) | val_mse=4.435e-04 | val_relL2=4.029e-02 | lr=2.0e-03
# Epoch 034 | train_tot=1.345e-02 (data=5.224e-04, phys=6.362e-03, ic=5.579e-04, bc=6.005e-03) | val_mse=3.811e-04 | val_relL2=3.714e-02 | lr=2.0e-03
# Epoch 035 | train_tot=1.348e-02 (data=5.470e-04, phys=6.387e-03, ic=5.759e-04, bc=5.967e-03) | val_mse=4.572e-04 | val_relL2=4.106e-02 | lr=2.0e-03
# Epoch 036 | train_tot=1.282e-02 (data=5.174e-04, phys=5.775e-03, ic=5.671e-04, bc=5.956e-03) | val_mse=4.152e-04 | val_relL2=3.873e-02 | lr=2.0e-03
# Epoch 037 | train_tot=1.268e-02 (data=4.707e-04, phys=5.746e-03, ic=5.371e-04, bc=5.926e-03) | val_mse=3.761e-04 | val_relL2=3.724e-02 | lr=2.0e-03
# Epoch 038 | train_tot=1.391e-02 (data=4.915e-04, phys=6.921e-03, ic=5.842e-04, bc=5.918e-03) | val_mse=4.552e-04 | val_relL2=4.131e-02 | lr=2.0e-03
# Epoch 039 | train_tot=1.374e-02 (data=5.116e-04, phys=6.720e-03, ic=6.050e-04, bc=5.898e-03) | val_mse=4.996e-04 | val_relL2=4.317e-02 | lr=2.0e-03
# Epoch 040 | train_tot=1.468e-02 (data=5.264e-04, phys=7.653e-03, ic=6.232e-04, bc=5.878e-03) | val_mse=4.475e-04 | val_relL2=4.023e-02 | lr=2.0e-03
# Epoch 041 | train_tot=1.397e-02 (data=5.190e-04, phys=6.978e-03, ic=5.832e-04, bc=5.892e-03) | val_mse=4.806e-04 | val_relL2=4.274e-02 | lr=2.0e-03
# Epoch 042 | train_tot=1.506e-02 (data=5.109e-04, phys=8.056e-03, ic=6.298e-04, bc=5.861e-03) | val_mse=4.367e-04 | val_relL2=4.036e-02 | lr=2.0e-03
# Epoch 043 | train_tot=1.678e-02 (data=5.484e-04, phys=9.668e-03, ic=7.142e-04, bc=5.847e-03) | val_mse=4.635e-04 | val_relL2=4.217e-02 | lr=2.0e-03
# Epoch 044 | train_tot=1.708e-02 (data=5.446e-04, phys=1.002e-02, ic=6.673e-04, bc=5.846e-03) | val_mse=4.262e-04 | val_relL2=3.963e-02 | lr=2.0e-03
# Epoch 045 | train_tot=1.700e-02 (data=5.205e-04, phys=1.001e-02, ic=6.304e-04, bc=5.840e-03) | val_mse=4.496e-04 | val_relL2=4.072e-02 | lr=2.0e-03
# Epoch 046 | train_tot=2.121e-02 (data=7.858e-04, phys=1.388e-02, ic=7.309e-04, bc=5.812e-03) | val_mse=7.320e-04 | val_relL2=5.295e-02 | lr=2.0e-03
# Epoch 047 | train_tot=2.240e-02 (data=8.733e-04, phys=1.487e-02, ic=8.254e-04, bc=5.822e-03) | val_mse=8.592e-04 | val_relL2=5.679e-02 | lr=2.0e-03
# Epoch 048 | train_tot=2.040e-02 (data=8.192e-04, phys=1.294e-02, ic=8.276e-04, bc=5.816e-03) | val_mse=8.805e-04 | val_relL2=5.791e-02 | lr=2.0e-03
# Epoch 049 | train_tot=1.940e-02 (data=7.709e-04, phys=1.194e-02, ic=8.649e-04, bc=5.821e-03) | val_mse=5.544e-04 | val_relL2=4.503e-02 | lr=2.0e-03
# Epoch 050 | train_tot=1.562e-02 (data=5.133e-04, phys=8.674e-03, ic=6.318e-04, bc=5.796e-03) | val_mse=4.609e-04 | val_relL2=4.182e-02 | lr=2.0e-03
# Epoch 051 | train_tot=1.449e-02 (data=4.703e-04, phys=7.642e-03, ic=5.936e-04, bc=5.780e-03) | val_mse=4.602e-04 | val_relL2=4.134e-02 | lr=2.0e-03
# Epoch 052 | train_tot=1.370e-02 (data=4.381e-04, phys=6.957e-03, ic=5.590e-04, bc=5.745e-03) | val_mse=3.643e-04 | val_relL2=3.652e-02 | lr=2.0e-03
# Epoch 053 | train_tot=1.244e-02 (data=4.055e-04, phys=5.749e-03, ic=5.460e-04, bc=5.735e-03) | val_mse=3.591e-04 | val_relL2=3.666e-02 | lr=2.0e-03
# Epoch 054 | train_tot=1.199e-02 (data=3.941e-04, phys=5.326e-03, ic=5.267e-04, bc=5.741e-03) | val_mse=4.052e-04 | val_relL2=3.857e-02 | lr=2.0e-03
# Epoch 055 | train_tot=1.219e-02 (data=3.810e-04, phys=5.567e-03, ic=5.365e-04, bc=5.705e-03) | val_mse=3.781e-04 | val_relL2=3.730e-02 | lr=2.0e-03
# Epoch 056 | train_tot=1.189e-02 (data=3.644e-04, phys=5.325e-03, ic=5.028e-04, bc=5.695e-03) | val_mse=2.910e-04 | val_relL2=3.234e-02 | lr=2.0e-03
# Epoch 057 | train_tot=1.175e-02 (data=3.377e-04, phys=5.226e-03, ic=5.011e-04, bc=5.685e-03) | val_mse=2.889e-04 | val_relL2=3.231e-02 | lr=2.0e-03
# Epoch 058 | train_tot=1.204e-02 (data=3.537e-04, phys=5.465e-03, ic=5.289e-04, bc=5.691e-03) | val_mse=3.067e-04 | val_relL2=3.349e-02 | lr=2.0e-03
# Epoch 059 | train_tot=1.174e-02 (data=3.453e-04, phys=5.207e-03, ic=5.144e-04, bc=5.678e-03) | val_mse=3.308e-04 | val_relL2=3.508e-02 | lr=2.0e-03
# Epoch 060 | train_tot=1.254e-02 (data=3.903e-04, phys=5.948e-03, ic=5.561e-04, bc=5.649e-03) | val_mse=3.368e-04 | val_relL2=3.480e-02 | lr=2.0e-03
# Epoch 061 | train_tot=1.250e-02 (data=3.584e-04, phys=5.960e-03, ic=5.307e-04, bc=5.654e-03) | val_mse=3.208e-04 | val_relL2=3.441e-02 | lr=2.0e-03
# Epoch 062 | train_tot=1.218e-02 (data=3.556e-04, phys=5.643e-03, ic=5.406e-04, bc=5.637e-03) | val_mse=3.263e-04 | val_relL2=3.497e-02 | lr=2.0e-03
# Epoch 063 | train_tot=1.234e-02 (data=3.702e-04, phys=5.794e-03, ic=5.323e-04, bc=5.645e-03) | val_mse=3.764e-04 | val_relL2=3.718e-02 | lr=2.0e-03
# Epoch 064 | train_tot=1.209e-02 (data=3.569e-04, phys=5.581e-03, ic=5.183e-04, bc=5.634e-03) | val_mse=3.043e-04 | val_relL2=3.327e-02 | lr=2.0e-03
# Epoch 065 | train_tot=1.215e-02 (data=3.605e-04, phys=5.617e-03, ic=5.448e-04, bc=5.628e-03) | val_mse=3.609e-04 | val_relL2=3.667e-02 | lr=2.0e-03
# Epoch 066 | train_tot=1.199e-02 (data=3.592e-04, phys=5.487e-03, ic=5.258e-04, bc=5.616e-03) | val_mse=3.004e-04 | val_relL2=3.353e-02 | lr=2.0e-03
# Epoch 067 | train_tot=1.136e-02 (data=3.530e-04, phys=4.853e-03, ic=5.301e-04, bc=5.621e-03) | val_mse=3.169e-04 | val_relL2=3.407e-02 | lr=2.0e-03
# Epoch 068 | train_tot=1.221e-02 (data=3.679e-04, phys=5.692e-03, ic=5.260e-04, bc=5.621e-03) | val_mse=4.151e-04 | val_relL2=3.942e-02 | lr=2.0e-03
# Epoch 069 | train_tot=1.313e-02 (data=3.910e-04, phys=6.604e-03, ic=5.532e-04, bc=5.585e-03) | val_mse=3.328e-04 | val_relL2=3.518e-02 | lr=2.0e-03
# Epoch 070 | train_tot=1.393e-02 (data=4.178e-04, phys=7.327e-03, ic=5.819e-04, bc=5.606e-03) | val_mse=3.543e-04 | val_relL2=3.641e-02 | lr=2.0e-03
# Epoch 071 | train_tot=1.380e-02 (data=3.822e-04, phys=7.223e-03, ic=5.827e-04, bc=5.609e-03) | val_mse=3.776e-04 | val_relL2=3.776e-02 | lr=2.0e-03
# Epoch 072 | train_tot=1.393e-02 (data=3.961e-04, phys=7.332e-03, ic=6.168e-04, bc=5.588e-03) | val_mse=3.867e-04 | val_relL2=3.814e-02 | lr=2.0e-03
# Epoch 073 | train_tot=1.462e-02 (data=4.158e-04, phys=8.034e-03, ic=5.844e-04, bc=5.585e-03) | val_mse=4.414e-04 | val_relL2=4.029e-02 | lr=2.0e-03
# Epoch 074 | train_tot=1.651e-02 (data=5.083e-04, phys=9.726e-03, ic=6.866e-04, bc=5.587e-03) | val_mse=4.912e-04 | val_relL2=4.317e-02 | lr=2.0e-03
# Epoch 075 | train_tot=1.729e-02 (data=5.699e-04, phys=1.044e-02, ic=6.832e-04, bc=5.600e-03) | val_mse=4.422e-04 | val_relL2=4.061e-02 | lr=2.0e-03
# Epoch 076 | train_tot=1.684e-02 (data=5.616e-04, phys=9.973e-03, ic=7.081e-04, bc=5.594e-03) | val_mse=6.142e-04 | val_relL2=4.847e-02 | lr=2.0e-03
# Epoch 077 | train_tot=1.550e-02 (data=4.908e-04, phys=8.758e-03, ic=6.493e-04, bc=5.603e-03) | val_mse=4.872e-04 | val_relL2=4.218e-02 | lr=2.0e-03
# Epoch 078 | train_tot=1.785e-02 (data=4.809e-04, phys=1.113e-02, ic=6.631e-04, bc=5.568e-03) | val_mse=4.679e-04 | val_relL2=4.227e-02 | lr=2.0e-03
# Epoch 079 | train_tot=1.860e-02 (data=5.146e-04, phys=1.177e-02, ic=7.247e-04, bc=5.595e-03) | val_mse=4.949e-04 | val_relL2=4.266e-02 | lr=2.0e-03
# Epoch 080 | train_tot=1.782e-02 (data=5.134e-04, phys=1.105e-02, ic=6.937e-04, bc=5.561e-03) | val_mse=4.613e-04 | val_relL2=4.170e-02 | lr=2.0e-03
# Epoch 081 | train_tot=1.651e-02 (data=4.260e-04, phys=9.861e-03, ic=6.409e-04, bc=5.585e-03) | val_mse=3.551e-04 | val_relL2=3.601e-02 | lr=2.0e-03
# Epoch 082 | train_tot=3.463e-02 (data=9.876e-04, phys=2.604e-02, ic=1.976e-03, bc=5.631e-03) | val_mse=1.649e-03 | val_relL2=7.897e-02 | lr=2.0e-03
# Epoch 083 | train_tot=4.797e-02 (data=1.389e-03, phys=3.797e-02, ic=2.534e-03, bc=6.074e-03) | val_mse=1.435e-03 | val_relL2=7.465e-02 | lr=2.0e-03
# Epoch 084 | train_tot=7.059e-02 (data=1.759e-03, phys=5.976e-02, ic=2.788e-03, bc=6.283e-03) | val_mse=1.385e-03 | val_relL2=7.334e-02 | lr=2.0e-03
# Epoch 085 | train_tot=8.149e-02 (data=2.804e-03, phys=6.666e-02, ic=5.801e-03, bc=6.227e-03) | val_mse=1.854e-03 | val_relL2=8.419e-02 | lr=2.0e-03
# Epoch 086 | train_tot=6.530e-02 (data=2.114e-03, phys=5.325e-02, ic=3.528e-03, bc=6.403e-03) | val_mse=1.413e-03 | val_relL2=7.319e-02 | lr=2.0e-03
# Epoch 087 | train_tot=4.729e-02 (data=1.463e-03, phys=3.761e-02, ic=1.872e-03, bc=6.352e-03) | val_mse=7.952e-04 | val_relL2=5.539e-02 | lr=2.0e-03
# Epoch 088 | train_tot=4.514e-02 (data=1.366e-03, phys=3.565e-02, ic=1.761e-03, bc=6.362e-03) | val_mse=7.681e-04 | val_relL2=5.366e-02 | lr=1.0e-03
# Epoch 089 | train_tot=2.552e-02 (data=7.757e-04, phys=1.736e-02, ic=1.064e-03, bc=6.321e-03) | val_mse=4.206e-04 | val_relL2=3.945e-02 | lr=1.0e-03
# Epoch 090 | train_tot=2.202e-02 (data=5.302e-04, phys=1.443e-02, ic=7.824e-04, bc=6.280e-03) | val_mse=3.860e-04 | val_relL2=3.709e-02 | lr=1.0e-03
# Epoch 091 | train_tot=1.680e-02 (data=4.488e-04, phys=9.416e-03, ic=7.008e-04, bc=6.233e-03) | val_mse=3.353e-04 | val_relL2=3.467e-02 | lr=1.0e-03
# Epoch 092 | train_tot=1.411e-02 (data=3.928e-04, phys=6.974e-03, ic=6.027e-04, bc=6.145e-03) | val_mse=3.170e-04 | val_relL2=3.351e-02 | lr=1.0e-03
# Epoch 093 | train_tot=1.228e-02 (data=3.558e-04, phys=5.290e-03, ic=5.436e-04, bc=6.091e-03) | val_mse=2.945e-04 | val_relL2=3.212e-02 | lr=1.0e-03
# Epoch 094 | train_tot=1.119e-02 (data=3.283e-04, phys=4.332e-03, ic=4.880e-04, bc=6.041e-03) | val_mse=2.991e-04 | val_relL2=3.269e-02 | lr=1.0e-03
# Epoch 095 | train_tot=1.070e-02 (data=3.130e-04, phys=3.913e-03, ic=4.653e-04, bc=6.008e-03) | val_mse=2.830e-04 | val_relL2=3.155e-02 | lr=1.0e-03
# Epoch 096 | train_tot=1.038e-02 (data=3.002e-04, phys=3.674e-03, ic=4.419e-04, bc=5.965e-03) | val_mse=2.729e-04 | val_relL2=3.096e-02 | lr=1.0e-03
# Epoch 097 | train_tot=1.018e-02 (data=2.901e-04, phys=3.511e-03, ic=4.326e-04, bc=5.945e-03) | val_mse=2.726e-04 | val_relL2=3.069e-02 | lr=1.0e-03
# Epoch 098 | train_tot=9.929e-03 (data=2.829e-04, phys=3.319e-03, ic=4.270e-04, bc=5.900e-03) | val_mse=2.532e-04 | val_relL2=3.012e-02 | lr=1.0e-03
# Epoch 099 | train_tot=9.758e-03 (data=2.764e-04, phys=3.171e-03, ic=4.223e-04, bc=5.889e-03) | val_mse=2.567e-04 | val_relL2=3.014e-02 | lr=1.0e-03
# Epoch 100 | train_tot=9.595e-03 (data=2.666e-04, phys=3.061e-03, ic=4.132e-04, bc=5.854e-03) | val_mse=2.403e-04 | val_relL2=2.934e-02 | lr=1.0e-03
# Epoch 101 | train_tot=9.488e-03 (data=2.677e-04, phys=2.968e-03, ic=4.182e-04, bc=5.833e-03) | val_mse=2.713e-04 | val_relL2=3.094e-02 | lr=1.0e-03
# Epoch 102 | train_tot=9.370e-03 (data=2.648e-04, phys=2.863e-03, ic=4.209e-04, bc=5.822e-03) | val_mse=2.655e-04 | val_relL2=3.071e-02 | lr=1.0e-03
# Epoch 103 | train_tot=9.244e-03 (data=2.512e-04, phys=2.794e-03, ic=4.086e-04, bc=5.790e-03) | val_mse=2.481e-04 | val_relL2=2.932e-02 | lr=1.0e-03
# Epoch 104 | train_tot=9.097e-03 (data=2.454e-04, phys=2.664e-03, ic=4.075e-04, bc=5.780e-03) | val_mse=2.468e-04 | val_relL2=2.923e-02 | lr=1.0e-03
# Epoch 105 | train_tot=9.017e-03 (data=2.447e-04, phys=2.603e-03, ic=4.100e-04, bc=5.759e-03) | val_mse=2.413e-04 | val_relL2=2.881e-02 | lr=1.0e-03
# Epoch 106 | train_tot=8.939e-03 (data=2.440e-04, phys=2.539e-03, ic=4.105e-04, bc=5.746e-03) | val_mse=2.452e-04 | val_relL2=2.933e-02 | lr=1.0e-03
# Epoch 107 | train_tot=8.856e-03 (data=2.377e-04, phys=2.471e-03, ic=4.077e-04, bc=5.740e-03) | val_mse=2.322e-04 | val_relL2=2.835e-02 | lr=1.0e-03
# Epoch 108 | train_tot=8.788e-03 (data=2.355e-04, phys=2.424e-03, ic=4.078e-04, bc=5.721e-03) | val_mse=2.360e-04 | val_relL2=2.859e-02 | lr=1.0e-03
# Epoch 109 | train_tot=8.707e-03 (data=2.297e-04, phys=2.356e-03, ic=4.051e-04, bc=5.717e-03) | val_mse=2.301e-04 | val_relL2=2.818e-02 | lr=1.0e-03
# Epoch 110 | train_tot=8.659e-03 (data=2.299e-04, phys=2.325e-03, ic=4.078e-04, bc=5.696e-03) | val_mse=2.371e-04 | val_relL2=2.832e-02 | lr=1.0e-03
# Epoch 111 | train_tot=8.646e-03 (data=2.298e-04, phys=2.317e-03, ic=4.092e-04, bc=5.690e-03) | val_mse=2.371e-04 | val_relL2=2.831e-02 | lr=1.0e-03
# Epoch 112 | train_tot=8.574e-03 (data=2.291e-04, phys=2.258e-03, ic=4.114e-04, bc=5.676e-03) | val_mse=2.271e-04 | val_relL2=2.784e-02 | lr=1.0e-03
# Epoch 113 | train_tot=8.519e-03 (data=2.260e-04, phys=2.212e-03, ic=4.119e-04, bc=5.669e-03) | val_mse=2.309e-04 | val_relL2=2.822e-02 | lr=1.0e-03
# Epoch 114 | train_tot=8.473e-03 (data=2.246e-04, phys=2.174e-03, ic=4.122e-04, bc=5.663e-03) | val_mse=2.247e-04 | val_relL2=2.770e-02 | lr=1.0e-03
# Epoch 115 | train_tot=8.434e-03 (data=2.225e-04, phys=2.149e-03, ic=4.098e-04, bc=5.652e-03) | val_mse=2.385e-04 | val_relL2=2.854e-02 | lr=1.0e-03
# Epoch 116 | train_tot=8.396e-03 (data=2.211e-04, phys=2.124e-03, ic=4.127e-04, bc=5.638e-03) | val_mse=2.288e-04 | val_relL2=2.781e-02 | lr=1.0e-03
# Epoch 117 | train_tot=8.337e-03 (data=2.182e-04, phys=2.065e-03, ic=4.097e-04, bc=5.644e-03) | val_mse=2.293e-04 | val_relL2=2.785e-02 | lr=1.0e-03
# Epoch 118 | train_tot=8.293e-03 (data=2.176e-04, phys=2.037e-03, ic=4.135e-04, bc=5.625e-03) | val_mse=2.218e-04 | val_relL2=2.741e-02 | lr=1.0e-03
# Epoch 119 | train_tot=8.256e-03 (data=2.163e-04, phys=2.001e-03, ic=4.158e-04, bc=5.623e-03) | val_mse=2.208e-04 | val_relL2=2.729e-02 | lr=1.0e-03
# Epoch 120 | train_tot=8.238e-03 (data=2.153e-04, phys=1.995e-03, ic=4.170e-04, bc=5.611e-03) | val_mse=2.160e-04 | val_relL2=2.704e-02 | lr=1.0e-03
# Epoch 121 | train_tot=8.209e-03 (data=2.124e-04, phys=1.968e-03, ic=4.164e-04, bc=5.612e-03) | val_mse=2.197e-04 | val_relL2=2.730e-02 | lr=1.0e-03
# Epoch 122 | train_tot=8.167e-03 (data=2.127e-04, phys=1.943e-03, ic=4.185e-04, bc=5.593e-03) | val_mse=2.158e-04 | val_relL2=2.682e-02 | lr=1.0e-03
# Epoch 123 | train_tot=8.157e-03 (data=2.129e-04, phys=1.930e-03, ic=4.184e-04, bc=5.596e-03) | val_mse=2.196e-04 | val_relL2=2.719e-02 | lr=1.0e-03
# Epoch 124 | train_tot=8.129e-03 (data=2.089e-04, phys=1.908e-03, ic=4.196e-04, bc=5.592e-03) | val_mse=2.198e-04 | val_relL2=2.714e-02 | lr=1.0e-03
# Epoch 125 | train_tot=8.116e-03 (data=2.121e-04, phys=1.904e-03, ic=4.168e-04, bc=5.584e-03) | val_mse=2.229e-04 | val_relL2=2.739e-02 | lr=1.0e-03
# Epoch 126 | train_tot=8.090e-03 (data=2.138e-04, phys=1.875e-03, ic=4.191e-04, bc=5.583e-03) | val_mse=2.261e-04 | val_relL2=2.756e-02 | lr=1.0e-03
# Epoch 127 | train_tot=8.081e-03 (data=2.118e-04, phys=1.872e-03, ic=4.241e-04, bc=5.572e-03) | val_mse=2.213e-04 | val_relL2=2.718e-02 | lr=1.0e-03
# Epoch 128 | train_tot=8.067e-03 (data=2.093e-04, phys=1.868e-03, ic=4.207e-04, bc=5.569e-03) | val_mse=2.127e-04 | val_relL2=2.644e-02 | lr=1.0e-03
# Epoch 129 | train_tot=8.021e-03 (data=2.085e-04, phys=1.825e-03, ic=4.222e-04, bc=5.566e-03) | val_mse=2.150e-04 | val_relL2=2.674e-02 | lr=1.0e-03
# Epoch 130 | train_tot=7.990e-03 (data=2.060e-04, phys=1.804e-03, ic=4.251e-04, bc=5.555e-03) | val_mse=2.089e-04 | val_relL2=2.638e-02 | lr=1.0e-03
# Epoch 131 | train_tot=7.971e-03 (data=2.064e-04, phys=1.781e-03, ic=4.229e-04, bc=5.561e-03) | val_mse=2.179e-04 | val_relL2=2.703e-02 | lr=1.0e-03
# Epoch 132 | train_tot=7.945e-03 (data=2.054e-04, phys=1.766e-03, ic=4.237e-04, bc=5.550e-03) | val_mse=2.143e-04 | val_relL2=2.655e-02 | lr=1.0e-03
# Epoch 133 | train_tot=7.917e-03 (data=2.054e-04, phys=1.742e-03, ic=4.250e-04, bc=5.545e-03) | val_mse=2.164e-04 | val_relL2=2.670e-02 | lr=1.0e-03
# Epoch 134 | train_tot=7.900e-03 (data=2.020e-04, phys=1.728e-03, ic=4.241e-04, bc=5.547e-03) | val_mse=2.153e-04 | val_relL2=2.673e-02 | lr=1.0e-03
# Epoch 135 | train_tot=7.900e-03 (data=2.059e-04, phys=1.733e-03, ic=4.270e-04, bc=5.533e-03) | val_mse=2.123e-04 | val_relL2=2.641e-02 | lr=1.0e-03
# Epoch 136 | train_tot=7.883e-03 (data=2.030e-04, phys=1.716e-03, ic=4.252e-04, bc=5.539e-03) | val_mse=2.158e-04 | val_relL2=2.656e-02 | lr=1.0e-03
# Epoch 137 | train_tot=7.858e-03 (data=2.048e-04, phys=1.694e-03, ic=4.271e-04, bc=5.532e-03) | val_mse=2.176e-04 | val_relL2=2.684e-02 | lr=1.0e-03
# Epoch 138 | train_tot=7.839e-03 (data=2.024e-04, phys=1.682e-03, ic=4.274e-04, bc=5.527e-03) | val_mse=2.081e-04 | val_relL2=2.604e-02 | lr=1.0e-03
# Epoch 139 | train_tot=7.828e-03 (data=2.004e-04, phys=1.676e-03, ic=4.298e-04, bc=5.523e-03) | val_mse=2.102e-04 | val_relL2=2.636e-02 | lr=1.0e-03
# Epoch 140 | train_tot=7.816e-03 (data=2.031e-04, phys=1.661e-03, ic=4.304e-04, bc=5.522e-03) | val_mse=2.147e-04 | val_relL2=2.658e-02 | lr=1.0e-03
# Epoch 141 | train_tot=7.805e-03 (data=2.008e-04, phys=1.653e-03, ic=4.314e-04, bc=5.520e-03) | val_mse=2.092e-04 | val_relL2=2.608e-02 | lr=1.0e-03
# Epoch 142 | train_tot=7.783e-03 (data=2.013e-04, phys=1.640e-03, ic=4.313e-04, bc=5.510e-03) | val_mse=2.079e-04 | val_relL2=2.629e-02 | lr=1.0e-03
# Epoch 143 | train_tot=7.760e-03 (data=1.981e-04, phys=1.617e-03, ic=4.313e-04, bc=5.513e-03) | val_mse=2.088e-04 | val_relL2=2.603e-02 | lr=1.0e-03
# Epoch 144 | train_tot=7.752e-03 (data=1.990e-04, phys=1.611e-03, ic=4.319e-04, bc=5.510e-03) | val_mse=2.100e-04 | val_relL2=2.615e-02 | lr=1.0e-03
# Epoch 145 | train_tot=7.735e-03 (data=1.985e-04, phys=1.599e-03, ic=4.323e-04, bc=5.506e-03) | val_mse=2.060e-04 | val_relL2=2.593e-02 | lr=1.0e-03
# Epoch 146 | train_tot=7.748e-03 (data=1.990e-04, phys=1.616e-03, ic=4.320e-04, bc=5.501e-03) | val_mse=2.091e-04 | val_relL2=2.603e-02 | lr=1.0e-03
# Epoch 147 | train_tot=7.735e-03 (data=1.970e-04, phys=1.601e-03, ic=4.350e-04, bc=5.501e-03) | val_mse=2.110e-04 | val_relL2=2.616e-02 | lr=1.0e-03
# Epoch 148 | train_tot=7.716e-03 (data=1.973e-04, phys=1.588e-03, ic=4.332e-04, bc=5.498e-03) | val_mse=2.088e-04 | val_relL2=2.596e-02 | lr=1.0e-03
# Epoch 149 | train_tot=7.695e-03 (data=1.962e-04, phys=1.568e-03, ic=4.331e-04, bc=5.498e-03) | val_mse=2.040e-04 | val_relL2=2.585e-02 | lr=1.0e-03
# Epoch 150 | train_tot=7.694e-03 (data=1.974e-04, phys=1.573e-03, ic=4.350e-04, bc=5.488e-03) | val_mse=2.083e-04 | val_relL2=2.583e-02 | lr=1.0e-03
# Epoch 151 | train_tot=7.703e-03 (data=1.997e-04, phys=1.573e-03, ic=4.349e-04, bc=5.496e-03) | val_mse=2.077e-04 | val_relL2=2.590e-02 | lr=1.0e-03
# Epoch 152 | train_tot=7.718e-03 (data=1.971e-04, phys=1.593e-03, ic=4.379e-04, bc=5.490e-03) | val_mse=2.089e-04 | val_relL2=2.597e-02 | lr=1.0e-03
# Epoch 153 | train_tot=7.711e-03 (data=1.976e-04, phys=1.593e-03, ic=4.379e-04, bc=5.483e-03) | val_mse=2.045e-04 | val_relL2=2.556e-02 | lr=1.0e-03
# Epoch 154 | train_tot=7.705e-03 (data=1.959e-04, phys=1.586e-03, ic=4.365e-04, bc=5.487e-03) | val_mse=2.022e-04 | val_relL2=2.551e-02 | lr=1.0e-03
# Epoch 155 | train_tot=7.728e-03 (data=1.989e-04, phys=1.607e-03, ic=4.388e-04, bc=5.483e-03) | val_mse=2.122e-04 | val_relL2=2.614e-02 | lr=1.0e-03
# Epoch 156 | train_tot=7.768e-03 (data=1.993e-04, phys=1.651e-03, ic=4.395e-04, bc=5.478e-03) | val_mse=2.087e-04 | val_relL2=2.590e-02 | lr=1.0e-03
# Epoch 157 | train_tot=7.736e-03 (data=1.952e-04, phys=1.621e-03, ic=4.360e-04, bc=5.484e-03) | val_mse=2.093e-04 | val_relL2=2.607e-02 | lr=1.0e-03
# Epoch 158 | train_tot=7.906e-03 (data=1.971e-04, phys=1.792e-03, ic=4.391e-04, bc=5.478e-03) | val_mse=2.120e-04 | val_relL2=2.639e-02 | lr=1.0e-03
# Epoch 159 | train_tot=7.808e-03 (data=2.016e-04, phys=1.691e-03, ic=4.386e-04, bc=5.476e-03) | val_mse=2.114e-04 | val_relL2=2.607e-02 | lr=1.0e-03
# Epoch 160 | train_tot=7.771e-03 (data=2.061e-04, phys=1.646e-03, ic=4.418e-04, bc=5.477e-03) | val_mse=2.284e-04 | val_relL2=2.738e-02 | lr=1.0e-03
# Epoch 161 | train_tot=7.748e-03 (data=2.027e-04, phys=1.630e-03, ic=4.446e-04, bc=5.470e-03) | val_mse=2.097e-04 | val_relL2=2.605e-02 | lr=1.0e-03
# Epoch 162 | train_tot=7.765e-03 (data=1.979e-04, phys=1.654e-03, ic=4.417e-04, bc=5.472e-03) | val_mse=2.127e-04 | val_relL2=2.617e-02 | lr=1.0e-03
# Epoch 163 | train_tot=7.803e-03 (data=1.978e-04, phys=1.693e-03, ic=4.418e-04, bc=5.470e-03) | val_mse=2.127e-04 | val_relL2=2.629e-02 | lr=1.0e-03
# Epoch 164 | train_tot=7.734e-03 (data=1.990e-04, phys=1.622e-03, ic=4.433e-04, bc=5.470e-03) | val_mse=2.157e-04 | val_relL2=2.649e-02 | lr=1.0e-03
# Epoch 165 | train_tot=7.725e-03 (data=1.985e-04, phys=1.623e-03, ic=4.439e-04, bc=5.459e-03) | val_mse=2.085e-04 | val_relL2=2.626e-02 | lr=1.0e-03
# Epoch 166 | train_tot=7.744e-03 (data=1.980e-04, phys=1.635e-03, ic=4.444e-04, bc=5.466e-03) | val_mse=2.024e-04 | val_relL2=2.548e-02 | lr=1.0e-03
# Epoch 167 | train_tot=7.657e-03 (data=1.943e-04, phys=1.553e-03, ic=4.438e-04, bc=5.466e-03) | val_mse=2.107e-04 | val_relL2=2.592e-02 | lr=1.0e-03
# Epoch 168 | train_tot=7.621e-03 (data=1.977e-04, phys=1.524e-03, ic=4.426e-04, bc=5.457e-03) | val_mse=2.022e-04 | val_relL2=2.532e-02 | lr=1.0e-03
# Epoch 169 | train_tot=7.575e-03 (data=1.957e-04, phys=1.480e-03, ic=4.429e-04, bc=5.457e-03) | val_mse=2.028e-04 | val_relL2=2.535e-02 | lr=1.0e-03
# Epoch 170 | train_tot=7.582e-03 (data=1.939e-04, phys=1.489e-03, ic=4.415e-04, bc=5.458e-03) | val_mse=2.026e-04 | val_relL2=2.531e-02 | lr=1.0e-03
# Epoch 171 | train_tot=7.647e-03 (data=1.941e-04, phys=1.551e-03, ic=4.425e-04, bc=5.459e-03) | val_mse=2.149e-04 | val_relL2=2.616e-02 | lr=1.0e-03
# Epoch 172 | train_tot=7.624e-03 (data=1.943e-04, phys=1.536e-03, ic=4.439e-04, bc=5.449e-03) | val_mse=2.003e-04 | val_relL2=2.516e-02 | lr=1.0e-03
# Epoch 173 | train_tot=7.649e-03 (data=1.912e-04, phys=1.561e-03, ic=4.436e-04, bc=5.454e-03) | val_mse=2.189e-04 | val_relL2=2.656e-02 | lr=1.0e-03
# Epoch 174 | train_tot=7.765e-03 (data=1.975e-04, phys=1.673e-03, ic=4.460e-04, bc=5.448e-03) | val_mse=2.069e-04 | val_relL2=2.573e-02 | lr=1.0e-03
# Epoch 175 | train_tot=7.670e-03 (data=1.946e-04, phys=1.575e-03, ic=4.463e-04, bc=5.455e-03) | val_mse=2.116e-04 | val_relL2=2.581e-02 | lr=1.0e-03
# Epoch 176 | train_tot=7.627e-03 (data=1.946e-04, phys=1.539e-03, ic=4.466e-04, bc=5.447e-03) | val_mse=2.034e-04 | val_relL2=2.541e-02 | lr=1.0e-03
# Epoch 177 | train_tot=7.608e-03 (data=1.945e-04, phys=1.520e-03, ic=4.465e-04, bc=5.446e-03) | val_mse=2.107e-04 | val_relL2=2.602e-02 | lr=1.0e-03
# Epoch 178 | train_tot=7.592e-03 (data=1.946e-04, phys=1.508e-03, ic=4.451e-04, bc=5.444e-03) | val_mse=2.026e-04 | val_relL2=2.540e-02 | lr=1.0e-03
# Epoch 179 | train_tot=7.582e-03 (data=1.921e-04, phys=1.496e-03, ic=4.431e-04, bc=5.451e-03) | val_mse=2.014e-04 | val_relL2=2.515e-02 | lr=1.0e-03
# Epoch 180 | train_tot=7.589e-03 (data=1.927e-04, phys=1.510e-03, ic=4.435e-04, bc=5.443e-03) | val_mse=2.084e-04 | val_relL2=2.572e-02 | lr=1.0e-03
# Epoch 181 | train_tot=7.608e-03 (data=1.928e-04, phys=1.531e-03, ic=4.452e-04, bc=5.440e-03) | val_mse=2.001e-04 | val_relL2=2.519e-02 | lr=1.0e-03
# Epoch 182 | train_tot=7.638e-03 (data=1.921e-04, phys=1.557e-03, ic=4.473e-04, bc=5.442e-03) | val_mse=2.065e-04 | val_relL2=2.558e-02 | lr=1.0e-03
# Epoch 183 | train_tot=7.588e-03 (data=1.936e-04, phys=1.509e-03, ic=4.462e-04, bc=5.440e-03) | val_mse=2.002e-04 | val_relL2=2.517e-02 | lr=1.0e-03
# Epoch 184 | train_tot=7.700e-03 (data=1.931e-04, phys=1.619e-03, ic=4.448e-04, bc=5.443e-03) | val_mse=2.119e-04 | val_relL2=2.583e-02 | lr=1.0e-03
# Epoch 185 | train_tot=7.745e-03 (data=1.949e-04, phys=1.661e-03, ic=4.508e-04, bc=5.438e-03) | val_mse=2.137e-04 | val_relL2=2.598e-02 | lr=1.0e-03
# Epoch 186 | train_tot=7.840e-03 (data=1.994e-04, phys=1.749e-03, ic=4.543e-04, bc=5.437e-03) | val_mse=2.237e-04 | val_relL2=2.659e-02 | lr=1.0e-03
# Epoch 187 | train_tot=7.843e-03 (data=1.998e-04, phys=1.747e-03, ic=4.588e-04, bc=5.437e-03) | val_mse=2.159e-04 | val_relL2=2.633e-02 | lr=1.0e-03
# Epoch 188 | train_tot=8.007e-03 (data=2.074e-04, phys=1.903e-03, ic=4.614e-04, bc=5.435e-03) | val_mse=2.285e-04 | val_relL2=2.725e-02 | lr=1.0e-03
# Epoch 189 | train_tot=8.178e-03 (data=2.064e-04, phys=2.070e-03, ic=4.610e-04, bc=5.441e-03) | val_mse=2.209e-04 | val_relL2=2.687e-02 | lr=1.0e-03
# Epoch 190 | train_tot=8.350e-03 (data=2.171e-04, phys=2.226e-03, ic=4.740e-04, bc=5.433e-03) | val_mse=2.168e-04 | val_relL2=2.660e-02 | lr=1.0e-03
# Epoch 191 | train_tot=8.254e-03 (data=2.147e-04, phys=2.138e-03, ic=4.665e-04, bc=5.435e-03) | val_mse=2.359e-04 | val_relL2=2.830e-02 | lr=1.0e-03
# Epoch 192 | train_tot=8.986e-03 (data=2.353e-04, phys=2.828e-03, ic=4.794e-04, bc=5.443e-03) | val_mse=2.478e-04 | val_relL2=2.895e-02 | lr=1.0e-03
# Epoch 193 | train_tot=9.465e-03 (data=2.557e-04, phys=3.264e-03, ic=5.030e-04, bc=5.442e-03) | val_mse=2.630e-04 | val_relL2=3.018e-02 | lr=1.0e-03
# Epoch 194 | train_tot=8.990e-03 (data=2.416e-04, phys=2.835e-03, ic=4.856e-04, bc=5.427e-03) | val_mse=2.648e-04 | val_relL2=3.047e-02 | lr=1.0e-03
# Epoch 195 | train_tot=8.847e-03 (data=2.404e-04, phys=2.688e-03, ic=4.808e-04, bc=5.438e-03) | val_mse=2.225e-04 | val_relL2=2.731e-02 | lr=1.0e-03
# Epoch 196 | train_tot=9.501e-03 (data=2.562e-04, phys=3.310e-03, ic=4.919e-04, bc=5.442e-03) | val_mse=2.869e-04 | val_relL2=3.157e-02 | lr=1.0e-03
# Epoch 197 | train_tot=1.023e-02 (data=2.856e-04, phys=4.001e-03, ic=5.170e-04, bc=5.428e-03) | val_mse=2.735e-04 | val_relL2=3.134e-02 | lr=1.0e-03
# Epoch 198 | train_tot=1.022e-02 (data=2.797e-04, phys=3.976e-03, ic=5.115e-04, bc=5.448e-03) | val_mse=3.554e-04 | val_relL2=3.569e-02 | lr=1.0e-03
# Epoch 199 | train_tot=1.079e-02 (data=2.914e-04, phys=4.516e-03, ic=5.275e-04, bc=5.454e-03) | val_mse=3.039e-04 | val_relL2=3.280e-02 | lr=1.0e-03
# Epoch 200 | train_tot=1.211e-02 (data=3.308e-04, phys=5.806e-03, ic=5.456e-04, bc=5.424e-03) | val_mse=3.032e-04 | val_relL2=3.291e-02 | lr=1.0e-03
# Epoch 201 | train_tot=1.105e-02 (data=3.085e-04, phys=4.737e-03, ic=5.553e-04, bc=5.448e-03) | val_mse=3.804e-04 | val_relL2=3.709e-02 | lr=1.0e-03
# Epoch 202 | train_tot=1.041e-02 (data=2.950e-04, phys=4.128e-03, ic=5.398e-04, bc=5.449e-03) | val_mse=2.695e-04 | val_relL2=3.049e-02 | lr=1.0e-03
# Epoch 203 | train_tot=9.292e-03 (data=2.562e-04, phys=3.097e-03, ic=4.955e-04, bc=5.444e-03) | val_mse=2.668e-04 | val_relL2=3.046e-02 | lr=1.0e-03
# Epoch 204 | train_tot=8.857e-03 (data=2.405e-04, phys=2.704e-03, ic=4.884e-04, bc=5.424e-03) | val_mse=2.288e-04 | val_relL2=2.765e-02 | lr=1.0e-03
# Epoch 205 | train_tot=9.092e-03 (data=2.393e-04, phys=2.931e-03, ic=4.783e-04, bc=5.444e-03) | val_mse=2.343e-04 | val_relL2=2.791e-02 | lr=1.0e-03
# Epoch 206 | train_tot=9.332e-03 (data=2.560e-04, phys=3.148e-03, ic=4.969e-04, bc=5.431e-03) | val_mse=2.514e-04 | val_relL2=2.951e-02 | lr=1.0e-03
# Epoch 207 | train_tot=8.935e-03 (data=2.429e-04, phys=2.768e-03, ic=5.016e-04, bc=5.422e-03) | val_mse=2.556e-04 | val_relL2=2.961e-02 | lr=1.0e-03
# Epoch 208 | train_tot=8.638e-03 (data=2.334e-04, phys=2.486e-03, ic=4.885e-04, bc=5.430e-03) | val_mse=2.373e-04 | val_relL2=2.846e-02 | lr=1.0e-03
# Epoch 209 | train_tot=8.260e-03 (data=2.216e-04, phys=2.128e-03, ic=4.759e-04, bc=5.434e-03) | val_mse=2.499e-04 | val_relL2=2.890e-02 | lr=1.0e-03
# Epoch 210 | train_tot=8.160e-03 (data=2.274e-04, phys=2.020e-03, ic=4.941e-04, bc=5.419e-03) | val_mse=2.317e-04 | val_relL2=2.791e-02 | lr=1.0e-03
# Epoch 211 | train_tot=7.993e-03 (data=2.160e-04, phys=1.876e-03, ic=4.770e-04, bc=5.424e-03) | val_mse=2.249e-04 | val_relL2=2.733e-02 | lr=1.0e-03
# Epoch 212 | train_tot=7.974e-03 (data=2.149e-04, phys=1.867e-03, ic=4.727e-04, bc=5.419e-03) | val_mse=2.176e-04 | val_relL2=2.682e-02 | lr=5.0e-04
# Epoch 213 | train_tot=7.661e-03 (data=2.000e-04, phys=1.580e-03, ic=4.601e-04, bc=5.420e-03) | val_mse=2.137e-04 | val_relL2=2.593e-02 | lr=5.0e-04
# Epoch 214 | train_tot=7.422e-03 (data=1.913e-04, phys=1.363e-03, ic=4.500e-04, bc=5.418e-03) | val_mse=2.016e-04 | val_relL2=2.485e-02 | lr=5.0e-04
# Epoch 215 | train_tot=7.328e-03 (data=1.876e-04, phys=1.278e-03, ic=4.471e-04, bc=5.415e-03) | val_mse=2.014e-04 | val_relL2=2.496e-02 | lr=5.0e-04
# Epoch 216 | train_tot=7.293e-03 (data=1.872e-04, phys=1.244e-03, ic=4.474e-04, bc=5.415e-03) | val_mse=1.990e-04 | val_relL2=2.459e-02 | lr=5.0e-04
# Epoch 217 | train_tot=7.273e-03 (data=1.863e-04, phys=1.226e-03, ic=4.477e-04, bc=5.414e-03) | val_mse=2.025e-04 | val_relL2=2.478e-02 | lr=5.0e-04
# Epoch 218 | train_tot=7.263e-03 (data=1.854e-04, phys=1.214e-03, ic=4.456e-04, bc=5.417e-03) | val_mse=2.026e-04 | val_relL2=2.480e-02 | lr=5.0e-04
# Epoch 219 | train_tot=7.257e-03 (data=1.852e-04, phys=1.211e-03, ic=4.466e-04, bc=5.415e-03) | val_mse=2.027e-04 | val_relL2=2.486e-02 | lr=5.0e-04
# Epoch 220 | train_tot=7.254e-03 (data=1.851e-04, phys=1.209e-03, ic=4.475e-04, bc=5.412e-03) | val_mse=2.011e-04 | val_relL2=2.470e-02 | lr=5.0e-04
# Epoch 221 | train_tot=7.254e-03 (data=1.853e-04, phys=1.209e-03, ic=4.470e-04, bc=5.413e-03) | val_mse=2.029e-04 | val_relL2=2.481e-02 | lr=5.0e-04
# Epoch 222 | train_tot=7.253e-03 (data=1.862e-04, phys=1.208e-03, ic=4.482e-04, bc=5.410e-03) | val_mse=1.993e-04 | val_relL2=2.453e-02 | lr=5.0e-04
# Epoch 223 | train_tot=7.248e-03 (data=1.848e-04, phys=1.204e-03, ic=4.468e-04, bc=5.413e-03) | val_mse=2.000e-04 | val_relL2=2.462e-02 | lr=5.0e-04
# Epoch 224 | train_tot=7.251e-03 (data=1.862e-04, phys=1.206e-03, ic=4.492e-04, bc=5.409e-03) | val_mse=1.991e-04 | val_relL2=2.455e-02 | lr=5.0e-04
# Epoch 225 | train_tot=7.245e-03 (data=1.851e-04, phys=1.200e-03, ic=4.481e-04, bc=5.412e-03) | val_mse=2.008e-04 | val_relL2=2.470e-02 | lr=5.0e-04
# Epoch 226 | train_tot=7.241e-03 (data=1.847e-04, phys=1.199e-03, ic=4.473e-04, bc=5.410e-03) | val_mse=1.992e-04 | val_relL2=2.446e-02 | lr=5.0e-04
# Epoch 227 | train_tot=7.239e-03 (data=1.844e-04, phys=1.196e-03, ic=4.473e-04, bc=5.411e-03) | val_mse=1.981e-04 | val_relL2=2.450e-02 | lr=5.0e-04
# Epoch 228 | train_tot=7.236e-03 (data=1.851e-04, phys=1.193e-03, ic=4.479e-04, bc=5.410e-03) | val_mse=1.977e-04 | val_relL2=2.454e-02 | lr=5.0e-04
# Epoch 229 | train_tot=7.232e-03 (data=1.854e-04, phys=1.191e-03, ic=4.485e-04, bc=5.407e-03) | val_mse=1.995e-04 | val_relL2=2.452e-02 | lr=5.0e-04
# Epoch 230 | train_tot=7.225e-03 (data=1.843e-04, phys=1.184e-03, ic=4.470e-04, bc=5.410e-03) | val_mse=1.987e-04 | val_relL2=2.447e-02 | lr=5.0e-04
# Epoch 231 | train_tot=7.221e-03 (data=1.841e-04, phys=1.182e-03, ic=4.479e-04, bc=5.407e-03) | val_mse=1.972e-04 | val_relL2=2.435e-02 | lr=5.0e-04
# Epoch 232 | train_tot=7.220e-03 (data=1.835e-04, phys=1.180e-03, ic=4.472e-04, bc=5.409e-03) | val_mse=1.982e-04 | val_relL2=2.442e-02 | lr=5.0e-04
# Epoch 233 | train_tot=7.219e-03 (data=1.848e-04, phys=1.182e-03, ic=4.487e-04, bc=5.404e-03) | val_mse=1.967e-04 | val_relL2=2.435e-02 | lr=5.0e-04
# Epoch 234 | train_tot=7.217e-03 (data=1.847e-04, phys=1.176e-03, ic=4.473e-04, bc=5.409e-03) | val_mse=2.014e-04 | val_relL2=2.468e-02 | lr=5.0e-04
# Epoch 235 | train_tot=7.216e-03 (data=1.840e-04, phys=1.176e-03, ic=4.481e-04, bc=5.407e-03) | val_mse=1.991e-04 | val_relL2=2.456e-02 | lr=5.0e-04
# Epoch 236 | train_tot=7.215e-03 (data=1.844e-04, phys=1.178e-03, ic=4.482e-04, bc=5.404e-03) | val_mse=2.000e-04 | val_relL2=2.456e-02 | lr=5.0e-04
# Epoch 237 | train_tot=7.215e-03 (data=1.839e-04, phys=1.176e-03, ic=4.471e-04, bc=5.408e-03) | val_mse=1.978e-04 | val_relL2=2.440e-02 | lr=5.0e-04
# Epoch 238 | train_tot=7.211e-03 (data=1.833e-04, phys=1.173e-03, ic=4.476e-04, bc=5.407e-03) | val_mse=1.980e-04 | val_relL2=2.435e-02 | lr=5.0e-04
# Epoch 239 | train_tot=7.209e-03 (data=1.837e-04, phys=1.172e-03, ic=4.476e-04, bc=5.406e-03) | val_mse=1.975e-04 | val_relL2=2.437e-02 | lr=5.0e-04
# Epoch 240 | train_tot=7.206e-03 (data=1.843e-04, phys=1.171e-03, ic=4.485e-04, bc=5.403e-03) | val_mse=1.984e-04 | val_relL2=2.451e-02 | lr=5.0e-04
# Epoch 241 | train_tot=7.205e-03 (data=1.837e-04, phys=1.168e-03, ic=4.473e-04, bc=5.406e-03) | val_mse=1.982e-04 | val_relL2=2.437e-02 | lr=5.0e-04
# Epoch 242 | train_tot=7.204e-03 (data=1.842e-04, phys=1.169e-03, ic=4.478e-04, bc=5.403e-03) | val_mse=2.013e-04 | val_relL2=2.458e-02 | lr=5.0e-04
# Epoch 243 | train_tot=7.200e-03 (data=1.836e-04, phys=1.163e-03, ic=4.481e-04, bc=5.405e-03) | val_mse=2.011e-04 | val_relL2=2.464e-02 | lr=5.0e-04
# Epoch 244 | train_tot=7.204e-03 (data=1.846e-04, phys=1.168e-03, ic=4.486e-04, bc=5.403e-03) | val_mse=1.982e-04 | val_relL2=2.434e-02 | lr=5.0e-04
# Epoch 245 | train_tot=7.203e-03 (data=1.835e-04, phys=1.166e-03, ic=4.484e-04, bc=5.404e-03) | val_mse=2.027e-04 | val_relL2=2.471e-02 | lr=5.0e-04
# Epoch 246 | train_tot=7.205e-03 (data=1.852e-04, phys=1.172e-03, ic=4.501e-04, bc=5.399e-03) | val_mse=1.988e-04 | val_relL2=2.446e-02 | lr=5.0e-04
# Epoch 247 | train_tot=7.201e-03 (data=1.834e-04, phys=1.167e-03, ic=4.478e-04, bc=5.403e-03) | val_mse=1.972e-04 | val_relL2=2.434e-02 | lr=5.0e-04
# Epoch 248 | train_tot=7.199e-03 (data=1.834e-04, phys=1.165e-03, ic=4.476e-04, bc=5.404e-03) | val_mse=1.993e-04 | val_relL2=2.443e-02 | lr=5.0e-04
# Epoch 249 | train_tot=7.193e-03 (data=1.836e-04, phys=1.159e-03, ic=4.483e-04, bc=5.402e-03) | val_mse=1.966e-04 | val_relL2=2.428e-02 | lr=5.0e-04
# Epoch 250 | train_tot=7.193e-03 (data=1.841e-04, phys=1.159e-03, ic=4.489e-04, bc=5.401e-03) | val_mse=2.011e-04 | val_relL2=2.457e-02 | lr=5.0e-04
# Epoch 251 | train_tot=7.193e-03 (data=1.829e-04, phys=1.159e-03, ic=4.477e-04, bc=5.403e-03) | val_mse=1.992e-04 | val_relL2=2.438e-02 | lr=5.0e-04
# Epoch 252 | train_tot=7.189e-03 (data=1.837e-04, phys=1.157e-03, ic=4.480e-04, bc=5.400e-03) | val_mse=1.997e-04 | val_relL2=2.441e-02 | lr=5.0e-04
# Epoch 253 | train_tot=7.185e-03 (data=1.840e-04, phys=1.154e-03, ic=4.493e-04, bc=5.398e-03) | val_mse=1.959e-04 | val_relL2=2.422e-02 | lr=5.0e-04
# Epoch 254 | train_tot=7.189e-03 (data=1.838e-04, phys=1.155e-03, ic=4.486e-04, bc=5.401e-03) | val_mse=1.982e-04 | val_relL2=2.438e-02 | lr=5.0e-04
# Epoch 255 | train_tot=7.189e-03 (data=1.840e-04, phys=1.156e-03, ic=4.481e-04, bc=5.401e-03) | val_mse=1.961e-04 | val_relL2=2.425e-02 | lr=5.0e-04
# Epoch 256 | train_tot=7.192e-03 (data=1.844e-04, phys=1.160e-03, ic=4.483e-04, bc=5.399e-03) | val_mse=1.967e-04 | val_relL2=2.438e-02 | lr=5.0e-04
# Epoch 257 | train_tot=7.191e-03 (data=1.847e-04, phys=1.158e-03, ic=4.489e-04, bc=5.400e-03) | val_mse=1.978e-04 | val_relL2=2.437e-02 | lr=5.0e-04
# Epoch 258 | train_tot=7.182e-03 (data=1.845e-04, phys=1.150e-03, ic=4.495e-04, bc=5.397e-03) | val_mse=1.999e-04 | val_relL2=2.442e-02 | lr=5.0e-04
# Epoch 259 | train_tot=7.178e-03 (data=1.835e-04, phys=1.147e-03, ic=4.484e-04, bc=5.399e-03) | val_mse=1.966e-04 | val_relL2=2.429e-02 | lr=5.0e-04
# Epoch 260 | train_tot=7.180e-03 (data=1.833e-04, phys=1.148e-03, ic=4.485e-04, bc=5.400e-03) | val_mse=2.000e-04 | val_relL2=2.441e-02 | lr=5.0e-04
# Epoch 261 | train_tot=7.179e-03 (data=1.841e-04, phys=1.150e-03, ic=4.487e-04, bc=5.396e-03) | val_mse=1.975e-04 | val_relL2=2.422e-02 | lr=5.0e-04
# Epoch 262 | train_tot=7.171e-03 (data=1.826e-04, phys=1.140e-03, ic=4.486e-04, bc=5.399e-03) | val_mse=1.965e-04 | val_relL2=2.422e-02 | lr=5.0e-04
# Epoch 263 | train_tot=7.167e-03 (data=1.830e-04, phys=1.141e-03, ic=4.482e-04, bc=5.395e-03) | val_mse=1.975e-04 | val_relL2=2.431e-02 | lr=5.0e-04
# Epoch 264 | train_tot=7.170e-03 (data=1.826e-04, phys=1.140e-03, ic=4.492e-04, bc=5.398e-03) | val_mse=1.953e-04 | val_relL2=2.410e-02 | lr=5.0e-04
# Epoch 265 | train_tot=7.171e-03 (data=1.828e-04, phys=1.143e-03, ic=4.491e-04, bc=5.396e-03) | val_mse=1.986e-04 | val_relL2=2.429e-02 | lr=5.0e-04
# Epoch 266 | train_tot=7.173e-03 (data=1.838e-04, phys=1.144e-03, ic=4.485e-04, bc=5.397e-03) | val_mse=1.987e-04 | val_relL2=2.450e-02 | lr=5.0e-04
# Epoch 267 | train_tot=7.174e-03 (data=1.829e-04, phys=1.147e-03, ic=4.494e-04, bc=5.395e-03) | val_mse=2.004e-04 | val_relL2=2.445e-02 | lr=5.0e-04
# Epoch 268 | train_tot=7.173e-03 (data=1.837e-04, phys=1.145e-03, ic=4.505e-04, bc=5.394e-03) | val_mse=1.941e-04 | val_relL2=2.406e-02 | lr=5.0e-04
# Epoch 269 | train_tot=7.171e-03 (data=1.828e-04, phys=1.142e-03, ic=4.498e-04, bc=5.396e-03) | val_mse=1.970e-04 | val_relL2=2.412e-02 | lr=5.0e-04
# Epoch 270 | train_tot=7.167e-03 (data=1.829e-04, phys=1.139e-03, ic=4.492e-04, bc=5.396e-03) | val_mse=1.953e-04 | val_relL2=2.409e-02 | lr=5.0e-04
# Epoch 271 | train_tot=7.172e-03 (data=1.826e-04, phys=1.147e-03, ic=4.483e-04, bc=5.394e-03) | val_mse=1.927e-04 | val_relL2=2.408e-02 | lr=5.0e-04
# Epoch 272 | train_tot=7.170e-03 (data=1.833e-04, phys=1.144e-03, ic=4.490e-04, bc=5.394e-03) | val_mse=1.967e-04 | val_relL2=2.417e-02 | lr=5.0e-04
# Epoch 273 | train_tot=7.165e-03 (data=1.824e-04, phys=1.139e-03, ic=4.489e-04, bc=5.395e-03) | val_mse=1.967e-04 | val_relL2=2.422e-02 | lr=5.0e-04
# Epoch 274 | train_tot=7.161e-03 (data=1.824e-04, phys=1.135e-03, ic=4.486e-04, bc=5.395e-03) | val_mse=1.969e-04 | val_relL2=2.416e-02 | lr=5.0e-04
# Epoch 275 | train_tot=7.170e-03 (data=1.828e-04, phys=1.144e-03, ic=4.493e-04, bc=5.394e-03) | val_mse=1.998e-04 | val_relL2=2.434e-02 | lr=5.0e-04
# Epoch 276 | train_tot=7.174e-03 (data=1.838e-04, phys=1.149e-03, ic=4.499e-04, bc=5.392e-03) | val_mse=1.964e-04 | val_relL2=2.415e-02 | lr=5.0e-04
# Epoch 277 | train_tot=7.173e-03 (data=1.828e-04, phys=1.149e-03, ic=4.493e-04, bc=5.392e-03) | val_mse=2.002e-04 | val_relL2=2.445e-02 | lr=5.0e-04
# Epoch 278 | train_tot=7.179e-03 (data=1.828e-04, phys=1.151e-03, ic=4.498e-04, bc=5.395e-03) | val_mse=1.984e-04 | val_relL2=2.431e-02 | lr=5.0e-04
# Epoch 279 | train_tot=7.175e-03 (data=1.831e-04, phys=1.150e-03, ic=4.498e-04, bc=5.392e-03) | val_mse=1.982e-04 | val_relL2=2.424e-02 | lr=5.0e-04
# Epoch 280 | train_tot=7.168e-03 (data=1.834e-04, phys=1.143e-03, ic=4.495e-04, bc=5.392e-03) | val_mse=1.977e-04 | val_relL2=2.427e-02 | lr=5.0e-04
# Epoch 281 | train_tot=7.177e-03 (data=1.831e-04, phys=1.153e-03, ic=4.501e-04, bc=5.391e-03) | val_mse=1.984e-04 | val_relL2=2.440e-02 | lr=5.0e-04
# Epoch 282 | train_tot=7.190e-03 (data=1.843e-04, phys=1.165e-03, ic=4.510e-04, bc=5.390e-03) | val_mse=1.980e-04 | val_relL2=2.431e-02 | lr=5.0e-04
# Epoch 283 | train_tot=7.184e-03 (data=1.836e-04, phys=1.157e-03, ic=4.489e-04, bc=5.395e-03) | val_mse=2.003e-04 | val_relL2=2.452e-02 | lr=5.0e-04
# Epoch 284 | train_tot=7.185e-03 (data=1.854e-04, phys=1.158e-03, ic=4.532e-04, bc=5.388e-03) | val_mse=2.002e-04 | val_relL2=2.445e-02 | lr=5.0e-04
# Epoch 285 | train_tot=7.178e-03 (data=1.837e-04, phys=1.152e-03, ic=4.506e-04, bc=5.392e-03) | val_mse=1.973e-04 | val_relL2=2.419e-02 | lr=5.0e-04
# Epoch 286 | train_tot=7.163e-03 (data=1.835e-04, phys=1.138e-03, ic=4.511e-04, bc=5.391e-03) | val_mse=1.999e-04 | val_relL2=2.443e-02 | lr=5.0e-04
# Epoch 287 | train_tot=7.187e-03 (data=1.850e-04, phys=1.163e-03, ic=4.498e-04, bc=5.390e-03) | val_mse=1.976e-04 | val_relL2=2.416e-02 | lr=5.0e-04
# Epoch 288 | train_tot=7.182e-03 (data=1.827e-04, phys=1.158e-03, ic=4.501e-04, bc=5.391e-03) | val_mse=2.018e-04 | val_relL2=2.444e-02 | lr=5.0e-04
# Epoch 289 | train_tot=7.206e-03 (data=1.844e-04, phys=1.181e-03, ic=4.516e-04, bc=5.389e-03) | val_mse=1.979e-04 | val_relL2=2.438e-02 | lr=5.0e-04
# Epoch 290 | train_tot=7.207e-03 (data=1.838e-04, phys=1.181e-03, ic=4.516e-04, bc=5.391e-03) | val_mse=1.958e-04 | val_relL2=2.417e-02 | lr=5.0e-04
# Epoch 291 | train_tot=7.196e-03 (data=1.833e-04, phys=1.171e-03, ic=4.510e-04, bc=5.391e-03) | val_mse=1.988e-04 | val_relL2=2.435e-02 | lr=5.0e-04
# Epoch 292 | train_tot=7.172e-03 (data=1.832e-04, phys=1.152e-03, ic=4.503e-04, bc=5.387e-03) | val_mse=1.993e-04 | val_relL2=2.426e-02 | lr=5.0e-04
# Epoch 293 | train_tot=7.167e-03 (data=1.825e-04, phys=1.144e-03, ic=4.499e-04, bc=5.391e-03) | val_mse=1.988e-04 | val_relL2=2.425e-02 | lr=5.0e-04
# Epoch 294 | train_tot=7.176e-03 (data=1.830e-04, phys=1.157e-03, ic=4.505e-04, bc=5.386e-03) | val_mse=1.947e-04 | val_relL2=2.396e-02 | lr=5.0e-04
# Epoch 295 | train_tot=7.178e-03 (data=1.830e-04, phys=1.155e-03, ic=4.501e-04, bc=5.390e-03) | val_mse=1.980e-04 | val_relL2=2.416e-02 | lr=5.0e-04
# Epoch 296 | train_tot=7.184e-03 (data=1.829e-04, phys=1.163e-03, ic=4.505e-04, bc=5.388e-03) | val_mse=1.955e-04 | val_relL2=2.403e-02 | lr=5.0e-04
# Epoch 297 | train_tot=7.205e-03 (data=1.846e-04, phys=1.183e-03, ic=4.519e-04, bc=5.385e-03) | val_mse=1.973e-04 | val_relL2=2.426e-02 | lr=5.0e-04
# Epoch 298 | train_tot=7.225e-03 (data=1.850e-04, phys=1.198e-03, ic=4.525e-04, bc=5.389e-03) | val_mse=2.010e-04 | val_relL2=2.454e-02 | lr=5.0e-04
# Epoch 299 | train_tot=7.240e-03 (data=1.857e-04, phys=1.216e-03, ic=4.518e-04, bc=5.387e-03) | val_mse=2.001e-04 | val_relL2=2.444e-02 | lr=5.0e-04
# Epoch 300 | train_tot=7.235e-03 (data=1.852e-04, phys=1.208e-03, ic=4.516e-04, bc=5.390e-03) | val_mse=1.974e-04 | val_relL2=2.443e-02 | lr=5.0e-04
# Best val_mse=1.927e-04 @ epoch 271
# Best val_relL2=2.396e-02 @ epoch 294
# === Inference (Nonlinear Diffusion–Reaction): f=0, IC='sine' ===
# Ref comparison: MSE=5.736e-04 | rel-L2=3.505e-02
#
# === Inference (Nonlinear Diffusion–Reaction): f=0, IC='two_mode' ===
# Ref comparison: MSE=7.533e-04 | rel-L2=4.391e-02
#
# === Inference (Nonlinear Diffusion–Reaction): f=0, IC='three_mode' ===
# Ref comparison: MSE=1.889e-03 | rel-L2=5.944e-02

# %%
def plot_training_losses(history):
    epochs = np.arange(1, len(history["tot"]) + 1)

    plt.figure(figsize=(4.0, 3.0))

    plt.plot(epochs, history["data"], label=r"$\mathcal{L}_{\text{data}}$")
    plt.plot(epochs, history["phys"], label=r"$\mathcal{L}_{\text{phys}}$")
    plt.plot(epochs, history["ic"],   label=r"$\mathcal{L}_{\text{IC}}$")
    plt.plot(epochs, history["bc"],   label=r"$\mathcal{L}_{\text{BC}}$")

    plt.yscale("log")

    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    # plt.title("Training loss components")
    plt.grid(alpha=0.3, linewidth=0.8)
    plt.legend(frameon=False)
    plt.tight_layout()
    plt.show()


# Plot the different components on the same figure
plot_training_losses(history)

# %%
def plot_3x4_summary(x, t, X, T, kinds, pred_dict, ref_dict):
    """
    3 x 4 figure:
      rows  = initial conditions
      cols:
        1) u(x,0)
        2) Exact solution
        3) FNO prediction
        4) Difference (pred - exact)
    """

    # Map kind -> label
    kind_label = {
        "sine":       "Single-Mode",
        "two_mode":   "Two-Mode",
        "three_mode": "Three-Mode",
    }

    nrows = len(kinds)
    ncols = 4
    fig, axes = plt.subplots(nrows, ncols,
                             figsize=(3.2*ncols, 2.4*nrows),
                             sharex=False, sharey=False)

    if nrows == 1:
        axes = np.array([axes])

    # ---------- Global color scale ----------
    all_true = np.concatenate([ref_dict[k].ravel() for k in kinds])
    all_pred = np.concatenate([pred_dict[k].ravel() for k in kinds])
    u_min = min(all_true.min(), all_pred.min())
    u_max = max(all_true.max(), all_pred.max())

    all_diff = np.concatenate([(pred_dict[k] - ref_dict[k]).ravel() for k in kinds])
    diff_max = np.max(np.abs(all_diff))

    extent = [x.min(), x.max(), t.min(), t.max()]

    # ---------- Column titles ----------
    col_titles = [
        r"$u(x,0)$",
        r"Exact : $u_{\mathrm{ref}}(x,t)$",
        r"FNO : $u_{\theta}(x,t)$",
        r"Error : $u_{\theta}-u_{\mathrm{ref}}$"
    ]
    for ci, title in enumerate(col_titles):
        axes[0, ci].set_title(title)

    # ---------- Fill the grid ----------
    for ri, kind in enumerate(kinds):

        u_ref  = ref_dict[kind]
        u_pred = pred_dict[kind]

        # (1) IC line plot
        ax_ic = axes[ri, 0]
        ax_ic.plot(x, u_ref[0], color="k")
        ax_ic.grid(alpha=0.3, linewidth=0.8)
        if ri == nrows - 1:
            ax_ic.set_xlabel(r"$x$")
        ax_ic.set_ylabel(kind_label[kind], fontsize=11)

        # (2) Exact solution
        ax_true = axes[ri, 1]
        im_true = ax_true.imshow(u_ref, aspect='auto', origin='lower',
                                 extent=extent, cmap="coolwarm",
                                 vmin=u_min, vmax=u_max)
        if ri == nrows - 1:
            ax_true.set_xlabel(r"$x$")
        ax_true.set_ylabel(r"$t$")
        fig.colorbar(im_true, ax=ax_true, fraction=0.046, pad=0.04)

        # (3) FNO prediction
        ax_pred = axes[ri, 2]
        im_pred = ax_pred.imshow(u_pred, aspect='auto', origin='lower',
                                 extent=extent, cmap="coolwarm",
                                 vmin=u_min, vmax=u_max)
        if ri == nrows - 1:
            ax_pred.set_xlabel(r"$x$")
        ax_pred.set_yticklabels([])
        fig.colorbar(im_pred, ax=ax_pred, fraction=0.046, pad=0.04)

        # (4) Difference
        diff = u_pred - u_ref
        ax_diff = axes[ri, 3]
        im_diff = ax_diff.imshow(diff, aspect='auto', origin='lower',
                                 extent=extent, cmap="bwr",
                                 vmin=-diff_max, vmax=diff_max)
        if ri == nrows - 1:
            ax_diff.set_xlabel(r"$x$")
        ax_diff.set_yticklabels([])
        fig.colorbar(im_diff, ax=ax_diff, fraction=0.046, pad=0.04)

    plt.tight_layout()
    plt.show()

# %%
# After the loop over kinds where you filled pred_dict[kind] and ref_dict[kind]
plot_3x4_summary(x, t, X, T, kinds, pred_dict, ref_dict)

# %%
def plot_time_slice_grid(x, t, kinds, pred_dict, ref_dict,
                         t_indices, t_labels):
    """
    Multi-panel figure:
      rows = time slices
      cols = IC types (Single-Mode / Two-Mode / Three-Mode)
      Each panel autos-scales its own ylim.
      Time labels (t = ...) appear in top-right.
    """

    kind_label = {
        "sine":       "Single-Mode",
        "two_mode":   "Two-Mode",
        "three_mode": "Three-Mode",
    }

    nrows = len(t_indices)
    ncols = len(kinds)
    fig, axes = plt.subplots(
        nrows, ncols,
        figsize=(3.0*ncols, 2.4*nrows),
        sharex=True,
        sharey=False
    )

    if nrows == 1:
        axes = np.array([axes])
    if ncols == 1:
        axes = axes[:, np.newaxis]

    # ---------- Column titles ----------
    for ci, kind in enumerate(kinds):
        axes[0, ci].set_title(kind_label.get(kind, kind))

    # ---------- Plotting ----------
    for ci, kind in enumerate(kinds):
        u_ref  = ref_dict[kind]
        u_pred = pred_dict[kind]

        for ri, (tidx, lbl_t) in enumerate(zip(t_indices, t_labels)):
            ax = axes[ri, ci]

            # Exact
            ax.plot(
                x, u_ref[tidx],
                linestyle="-",
                color="C0",
                linewidth=3.2,
                label="Exact"
            )

            # FNO
            ax.plot(
                x, u_pred[tidx],
                linestyle="--",
                color="C1",
                linewidth=3.0,
                label="FNO"
            )

            # x-label last row
            if ri == nrows - 1:
                ax.set_xlabel(r"$x$")

            # y-label first column
            if ci == 0:
                ax.set_ylabel(r"$u(x,t)$")

            # ---------- Time label moved to TOP-RIGHT ----------
            ax.text(
                0.98, 0.98,              # <--- position: top-right corner
                lbl_t,
                transform=ax.transAxes,
                fontsize=9,
                ha="right",
                va="top"
            )

            ax.grid(alpha=0.2, linewidth=0.8)

    # ---------- Global legend ----------
    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels,
               loc="upper center", ncol=2,
               frameon=False,
               bbox_to_anchor=(0.5, 1.02))

    plt.tight_layout()
    plt.show()

# %%
# Choose time indices for slice plots, including t ≈ 0.75
idx_0     = 0
idx_mid   = Nt // 2

t_target  = 0.75 * Tfinal       # here Tfinal = 1.0
idx_075   = int(np.argmin(np.abs(t - t_target)))
idx_final = Nt - 1

t_indices = [idx_0, idx_mid, idx_final]
t_labels  = [rf"$t = {t[idx_0]:.2f}$",
             rf"$t = {t[idx_mid]:.2f}$",
             rf"$t = {t[idx_final]:.2f}$"]

plot_time_slice_grid(x, t, kinds, pred_dict, ref_dict, t_indices, t_labels)
